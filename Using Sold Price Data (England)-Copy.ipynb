# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Carl\\Housing'

# %%
os.chdir("C:\\Users\\Carl\\Housing")

# %%
import pandas as pd
import statistics
import os
import re
from operator import *
pd.set_option('display.max_rows', None)
os.getcwd()
# Out:
# 'C:\\Users\\Carl\\Housing'

# %%
columns=["Transaction unique identifier","Price","Date of Transfer","Postcode","Property Type","Old/New","Duration","PAON","SAON","Street","Locality","Town/City","District","County","PPD Category Type","TBD"]

print("Train times with Postcodes loading...")
postcodes_with_train_times_df=pd.read_excel("C:\\Users\\Carl\\Housing\\Data\\postcodedfwithtimedf.xlsx")
print("Train times loaded")

print("Price paid data loading...")
pp2022=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2022.csv")
pp2022.columns=columns
print("price paid data loaded")

print("postcode to LA mapping loading...")
postcodemappings=pd.read_csv(open("C:\\Users\\Carl\\Housing\\Data\\Postcode to LA.csv"),sep='\t',error_bad_lines=False)
postcodemappings=postcodemappings[postcodemappings.columns[0]].str.split(',',expand=True)
pmcols=["Postcode 1","Postcode 2","Postcode 3","County Code","County Name","Local Authority Code","Local Authority Name","None"]
postcodemappings.columns=pmcols
postcodemappings=postcodemappings[["Postcode 1","Postcode 2","Postcode 3","County Code","County Name","Local Authority Code","Local Authority Name"]]
postcodemappings["Local Authority Name"]=postcodemappings["Local Authority Name"].str.rstrip()
postcodemappings["Local Authority Name"]=postcodemappings["Local Authority Name"].str.lstrip()
postcodemappings["Local Authority Name"]=postcodemappings["Local Authority Name"].str.upper()
print("postcode to LA mapping loaded")

print("Dep Scores for England Loading...")
deprivation_scores=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\EIMD Data.xlsx','rb'),"IMD2019")
deprivation_scores=deprivation_scores.rename(columns={"Local Authority District name (2019)":"Local Authority Name"})
deprivation_scores["Local Authority Name"]=deprivation_scores["Local Authority Name"].str.rstrip()
deprivation_scores["Local Authority Name"]=deprivation_scores["Local Authority Name"].str.lstrip()
deprivation_scores["Local Authority Name"]=deprivation_scores["Local Authority Name"].str.upper()
print("Dep Scores for England loaded...")

print("Retail info loading...")
retail_info=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\RetailInfo.xlsx','rb'),"Table 1",usecols=[1,7],skiprows=range(5))
retail_info=retail_info.dropna()
retail_info=retail_info.rename(columns={"Unnamed: 1":"Local Authority","47 : Retail":"Count"})
retail_info["Local Authority"]=retail_info["Local Authority"].str.rstrip()
retail_info["Local Authority"]=retail_info["Local Authority"].str.lstrip()
retail_info["Local Authority"]=retail_info["Local Authority"].str.upper()
retail_info.set_index("Local Authority",inplace=True)
retail_infodict=retail_info.to_dict(orient="index")
print("Retail info loaded")


print("Crime Data Loading...")
crimedf=pd.read_excel(open("C:\\Users\\Carl\\Housing\\Data\\Crime Data.xlsx","rb"),"Table C3",skiprows=range(6))
crimedf.columns=[string.replace("\n","") for string in list(crimedf.columns)]
crimedf=crimedf[["Local Authority name","Total recorded crime (excluding fraud)"]]
crimedf["Local Authority name"]=crimedf["Local Authority name"].str.rstrip()
crimedf["Local Authority name"]=crimedf["Local Authority name"].str.lstrip()
crimedf["Local Authority name"]=crimedf["Local Authority name"].str.upper()
crimedf.dropna(subset=["Local Authority name"],inplace=True)
crimedf=crimedf.set_index("Local Authority name")
crimedfdict=crimedf.to_dict(orient="index")
print("Crime Data Loaded")

print("population info starting...")
population_info=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\Population Figures (england and wales).xlsx','rb'),"P01",usecols=[1,2],skiprows=range(6))
population_info=population_info.dropna()
population_info=population_info.rename(columns={"Area name":"Local Authority","All persons":"Population"})
population_info["Local Authority"]=population_info["Local Authority"].str.rstrip()
population_info["Local Authority"]=population_info["Local Authority"].str.lstrip()
population_info["Local Authority"]=population_info["Local Authority"].str.upper()
population_info.set_index("Local Authority",inplace=True)
population_infodict=population_info.to_dict(orient="index")
print("population info done")


print("area size info starting...")
areasizeinfo=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\SAM_LAD_DEC_2020_UK.xlsx','rb'),"SAM_LAD_2020",usecols=[1,2])
areasizeinfo=areasizeinfo.dropna()
areasizeinfo.rename(columns={"LAD20NM":"Local Authority","AREAEHECT":"Area (Hectares)"},inplace=True)
areasizeinfo["Local Authority"]=areasizeinfo["Local Authority"].str.rstrip()
areasizeinfo["Local Authority"]=areasizeinfo["Local Authority"].str.lstrip()
areasizeinfo["Local Authority"]=areasizeinfo["Local Authority"].str.upper()
areasizeinfo.set_index("Local Authority",inplace=True)
areasizeinfodict=areasizeinfo.to_dict(orient="index")
print("area size info done")


print("Beach Info Loading...")
beachdf=pd.read_excel(open("C:\\Users\\Carl\\Housing\\Data\\Beaches and Bathing Sites in England\\Beaches in England w postcodes.xlsx","rb"))
beachdf=beachdf.drop(columns=["Unnamed: 0","Unnamed: 0.1"])
beachcountdf=beachdf["first postcode wo num"].value_counts().to_frame()
beachcountdict=beachcountdf.to_dict()
beachcountdict=list(beachcountdict.values())[0]
beachcountdict
print("Beach Info Loaded")


print("Green Data starting...")
enggreendf=pd.read_excel("C:\\Users\\Carl\\Housing\\Data\\Green Space Data England LAs.xlsx")
enggreendf=enggreendf.rename(columns={"Unnamed: 0":"Local Authority"})
enggreendf=enggreendf.set_index("Local Authority")
print("Green Data finished...")

print("all loaded!")
# Out:
# Train times with Postcodes loading...
# Train times loaded
# Price paid data loading...
# price paid data loaded
# postcode to LA mapping loading...
# postcode to LA mapping loaded
# Dep Scores for England Loading...
# Dep Scores for England loaded...
# Retail info loading...
# Retail info loaded
# Crime Data Loading...
# Crime Data Loaded
# population info starting...
# population info done
# area size info starting...
# area size info done
# Beach Info Loading...
# Beach Info Loaded
# Green Data starting...
# Green Data finished...
# all loaded!

# %%
beachcountdict
# Out:
# {'TR': 50,
#  'PL': 39,
#  'TQ': 32,
#  'EX': 31,
#  'PO': 31,
#  'BH': 27,
#  'CT': 23,
#  'NE': 19,
#  'NR': 15,
#  'YO': 15,
#  'DT': 14,
#  'BN': 14,
#  'TS': 12,
#  'LA': 11,
#  'CO': 10,
#  'SS': 8,
#  'TN': 8,
#  'FY': 8,
#  'TA': 7,
#  'PE': 7,
#  'CA': 5,
#  'BS': 5,
#  'SR': 4,
#  'IP': 4,
#  'CH': 4,
#  'LN': 3,
#  'HU': 3,
#  'SO': 3,
#  'ME': 3,
#  'PR': 2,
#  'N': 2,
#  'DN': 2,
#  'GU': 1,
#  'OX': 1,
#  'NW': 1,
#  'SW': 1,
#  'L': 1,
#  'LS': 1,
#  'TD': 1,
#  'GL': 1,
#  'NG': 1}

# %%
postcodes_with_train_times_df.head()
# Out:
#    Unnamed: 0                   station_name  postcode   latitude  longitude  \
# 0           0  Alexandra Palace Rail Station   N22 7SS  51.597925  -0.120210
# 1           1          Achanalt Rail Station  IV23 2QD  57.609576  -4.913846
# 2           2          Aberdare Rail Station  CF44 7BP  51.715060  -3.443095
# 3           3        Altnabreac Rail Station  KW12 6UR  58.388133  -3.706287
# 4           4          Aberdeen Rail Station  AB11 6LX  57.143687  -2.098693
#
#    train time to work First Postcode
# 0           44.966667            N22
# 1          957.300000           IV23
# 2          436.133333           CF44
# 3         1055.300000           KW12
# 4          698.300000           AB11

# %%
pp2022.head()
# Out:
#             Transaction unique identifier   Price  Date of Transfer  Postcode  \
# 0  {DE2D0CDF-7EE0-51EE-E053-6C04A8C00671}  250000  2022-03-16 00:00  EX31 3UX
# 1  {DE2D0CDF-7EE1-51EE-E053-6C04A8C00671}  210000  2022-03-18 00:00  TQ12 1GU
# 2  {DE2D0CDF-7EE2-51EE-E053-6C04A8C00671}  333000  2022-03-23 00:00   EX8 4QD
# 3  {DE2D0CDF-7EE6-51EE-E053-6C04A8C00671}  137000  2022-01-21 00:00   EX2 5AR
# 4  {DE2D0CDF-7EE9-51EE-E053-6C04A8C00671}  375550  2022-03-03 00:00  EX31 3FW
#
#   Property Type Old/New Duration PAON SAON                 Street    Locality  \
# 0             S       N        F    2  NaN            POTTERSWELL  ROUNDSWELL
# 1             D       N        F    1  NaN            BURNET ROAD         NaN
# 2             D       N        F   11  NaN  MOUNT PLEASANT AVENUE         NaN
# 3             F       N        L   38  NaN              LANSDOWNE         NaN
# 4             D       N        F    2  NaN            SWORD CLOSE  FREMINGTON
#
#       Town/City     District County PPD Category Type TBD
# 0    BARNSTAPLE  NORTH DEVON  DEVON                 A   A
# 1  NEWTON ABBOT  TEIGNBRIDGE  DEVON                 A   A
# 2       EXMOUTH   EAST DEVON  DEVON                 A   A
# 3        EXETER       EXETER  DEVON                 A   A
# 4    BARNSTAPLE  NORTH DEVON  DEVON                 A   A

# %%
postcodemappings.head()
# Out:
#   Postcode 1 Postcode 2 Postcode 3 County Code   County Name  \
# 0    OX277JB   OX27 7JB   OX27 7JB   E10000025   Oxfordshire
# 1    NR205NQ   NR20 5NQ   NR20 5NQ   E10000020       Norfolk
# 2    GU214YG   GU21 4YG   GU21 4YG   E10000030        Surrey
# 3    GU220AJ   GU22 0AJ   GU22 0AJ   E10000030        Surrey
# 4    DA8 1DN   DA8  1DN    DA8 1DN   E13000002  Outer London
#
#   Local Authority Code Local Authority Name
# 0            E07000177             CHERWELL
# 1            E07000143            BRECKLAND
# 2            E07000217               WOKING
# 3            E07000217               WOKING
# 4            E09000004               BEXLEY

# %%
deprivation_scores.head()
# Out:
#   LSOA code (2011)           LSOA name (2011)  \
# 0        E01000001        City of London 001A
# 1        E01000002        City of London 001B
# 2        E01000003        City of London 001C
# 3        E01000005        City of London 001E
# 4        E01000006  Barking and Dagenham 016A
#
#   Local Authority District code (2019)  Local Authority Name  \
# 0                            E09000001        CITY OF LONDON
# 1                            E09000001        CITY OF LONDON
# 2                            E09000001        CITY OF LONDON
# 3                            E09000001        CITY OF LONDON
# 4                            E09000002  BARKING AND DAGENHAM
#
#    Index of Multiple Deprivation (IMD) Rank  \
# 0                                     29199
# 1                                     30379
# 2                                     14915
# 3                                      8678
# 4                                     14486
#
#    Index of Multiple Deprivation (IMD) Decile
# 0                                           9
# 1                                          10
# 2                                           5
# 3                                           3
# 4                                           5

# %%
retail_info.head()
# Out:
#                       Count
# Local Authority
# UNITED KINGDOM     220685.0
# GREAT BRITAIN      214865.0
# ENGLAND AND WALES  201270.0
# ENGLAND            192870.0
# NORTH EAST           6090.0

# %%
crimedf.head()
# Out:
#                               Total recorded crime (excluding fraud)
# Local Authority name
# BATH AND NORTH EAST SOMERSET                                   12299
# BRISTOL, CITY OF                                               53868
# NORTH SOMERSET                                                 14848
# SOUTH GLOUCESTERSHIRE                                          17168
# BEDFORD                                                        15012

# %%
population_info.head()
# Out:
#                    Population
# Local Authority
# ENGLAND AND WALES    59597300
# ENGLAND              56489800
# NORTH EAST            2647100
# COUNTY DURHAM          522100
# DARLINGTON             107800

# %%
areasizeinfo.head()
# Out:
#                       Area (Hectares)
# Local Authority
# HARTLEPOOL                    9834.66
# MIDDLESBROUGH                 5455.37
# REDCAR AND CLEVELAND         25378.57
# STOCKTON-ON-TEES             20973.09
# DARLINGTON                   19747.58

# %%
beachdf.head()
# Out:
#           EUBWID                    label              district        lat  \
# 0  ukc1101-06000       Seaton Carew North            Hartlepool  54.664667
# 1  ukc1101-06100      Seaton Carew Centre            Hartlepool  54.659913
# 2  ukc1101-06200  Seaton Carew North Gare            Hartlepool  54.649630
# 3  ukc1202-06300           Redcar Coatham  Redcar and Cleveland  54.622067
# 4  ukc1202-06400  Redcar Lifeboat Station  Redcar and Cleveland  54.620056
#
#        long  postcode first postcode first postcode wo num
# 0 -1.186043  TS25 1AP           TS25                    TS
# 1 -1.180728  TS25 1BU           TS25                    TS
# 2 -1.164661  TS25 2DT           TS25                    TS
# 3 -1.081593  TS10 5BJ           TS10                    TS
# 4 -1.060762  TS10 3DB           TS10                    TS

# %%
enggreendf.head()
# Out:
#                  Median distance to nearest park or public garden (m)  \
# Local Authority
# BIRMINGHAM                                              461.546330
# LEEDS                                                   589.914400
# SHEFFIELD                                               448.230415
# CORNWALL                                               1511.147750
# COUNTY DURHAM                                           975.127175
#
#                  Median size of nearest park or public garden (m2)  \
# Local Authority
# BIRMINGHAM                                             84248.69225
# LEEDS                                                  42704.57395
# SHEFFIELD                                              40165.21745
# CORNWALL                                                9200.62555
# COUNTY DURHAM                                          21699.60425
#
#                  Median number of parks and public gardens in 1,000 m radius  \
# Local Authority
# BIRMINGHAM                                                       2
# LEEDS                                                            1
# SHEFFIELD                                                        2
# CORNWALL                                                         1
# COUNTY DURHAM                                                    1
#
#                  Median combined size of parks and public gardens in 1,000 m radius (m2)  \
# Local Authority
# BIRMINGHAM                                                222966.0
# LEEDS                                                     116125.0
# SHEFFIELD                                                 169379.0
# CORNWALL                                                   11941.0
# COUNTY DURHAM                                              36942.0
#
#                  Median population per park or public garden  \
# Local Authority
# BIRMINGHAM                                      21009.100646
# LEEDS                                           14123.402186
# SHEFFIELD                                       13118.295408
# CORNWALL                                         9871.597800
# COUNTY DURHAM                                    8811.728221
#
#                  Number of flats in rural and built up areas  \
# Local Authority
# BIRMINGHAM                                            126778
# LEEDS                                                  84651
# SHEFFIELD                                              67958
# CORNWALL                                               53151
# COUNTY DURHAM                                          22139
#
#                  Number of houses in rural and built up area  \
# Local Authority
# BIRMINGHAM                                            320659
# LEEDS                                                 267797
# SHEFFIELD                                             188826
# CORNWALL                                              223995
# COUNTY DURHAM                                         226057
#
#                  Median distance to nearest park or public garden (m) (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                0.116508
# LEEDS                                                     0.148911
# SHEFFIELD                                                 0.113146
# CORNWALL                                                  0.381457
# COUNTY DURHAM                                             0.246150
#
#                  Median size of nearest park or public garden (m2) (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                0.055587
# LEEDS                                                     0.028176
# SHEFFIELD                                                 0.026501
# CORNWALL                                                  0.006071
# COUNTY DURHAM                                             0.014317
#
#                  Median number of parks and public gardens in 1,000 m radius (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                0.153846
# LEEDS                                                     0.076923
# SHEFFIELD                                                 0.153846
# CORNWALL                                                  0.076923
# COUNTY DURHAM                                             0.076923
#
#                  Median combined size of parks and public gardens in 1,000 m radius (m2) (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                0.098511
# LEEDS                                                     0.051307
# SHEFFIELD                                                 0.074835
# CORNWALL                                                  0.005276
# COUNTY DURHAM                                             0.016322
#
#                  Median population per park or public garden (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                0.338971
# LEEDS                                                     0.227874
# SHEFFIELD                                                 0.211657
# CORNWALL                                                  0.159273
# COUNTY DURHAM                                             0.142173
#
#                  Number of flats in rural and built up areas (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                1.000000
# LEEDS                                                     0.667710
# SHEFFIELD                                                 0.536039
# CORNWALL                                                  0.419245
# COUNTY DURHAM                                             0.174628
#
#                  Number of houses in rural and built up area (Relative to Max)  \
# Local Authority
# BIRMINGHAM                                                1.000000
# LEEDS                                                     0.835146
# SHEFFIELD                                                 0.588869
# CORNWALL                                                  0.698546
# COUNTY DURHAM                                             0.704976
#
#                  Green Score (Raw)  Green Score (Relative to Max)
# Local Authority
# BIRMINGHAM                0.290618                       0.072202
# LEEDS                     0.225153                       0.055937
# SHEFFIELD                 0.353569                       0.087841
# CORNWALL                  0.033124                       0.008229
# COUNTY DURHAM             0.114802                       0.028522

# %% [markdown]
# # Flat Calculations

# %%
pd.set_option('display.max_rows', None)
#pp2020=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2020.csv")
#pp2020.columns=columns
#pp2021=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2021.csv")
#pp2021.columns=columns

print("shape of input df is",pp2022.shape)

pp2022['Property Type']=pp2022["Property Type"].str.replace("D","Detached")
pp2022['Property Type']=pp2022["Property Type"].str.replace("S","Semi-Detached")
pp2022['Property Type']=pp2022["Property Type"].str.replace("T","Terraced")
pp2022['Property Type']=pp2022["Property Type"].str.replace("F","Flat")
pp2022["Property Type"]=pp2022["Property Type"].str.replace("O","Other")

print("\nthis is the breakdown by house type across all UK\n",pp2022["Property Type"].value_counts())

hpp2022=pp2022[pp2022["Property Type"].isin(["Flat"])]
print("\n houses sold since 2022\n",hpp2022.shape)

hpp2022.reset_index(inplace=True,drop=True)

hpp2022.dropna(subset=["Postcode"],inplace=True)
hpp2022.reset_index(inplace=True,drop=True)

hpp2022dict=hpp2022.to_dict(orient="index")
print("hpp2022dict[2]=",hpp2022dict[2])

for i in range(0,len(hpp2022)):
    try:
        postcode=list(hpp2022dict.get(i).items())[3][1]
        first_postcode=postcode.split(" ")[0]
        hpp2022dict[i]["First Postcode"]=first_postcode
    except:
        print(postcode)
print("\nHouse price dictionary since 2022 has",len(hpp2022dict.keys()),"keys\n")

hpp2022dictdf=pd.DataFrame.from_dict(hpp2022dict,orient="index")
print("\nHouse price dictionary df (with split postcode) since 2022 has",hpp2022dictdf.shape[0],"rows")

hpp2022dictdf['Month of Transfer'] = pd.DatetimeIndex(hpp2022dictdf['Date of Transfer']).month
hpp2022dictdf['Month of Transfer']=hpp2022dictdf['Month of Transfer'].replace(1,"January")
hpp2022dictdf['Month of Transfer']=hpp2022dictdf['Month of Transfer'].replace(2,"Febuary")
hpp2022dictdf['Month of Transfer']=hpp2022dictdf['Month of Transfer'].replace(3,"March")
hpp2022dictdf['Month of Transfer']=hpp2022dictdf['Month of Transfer'].replace(4,"April")
hpp2022dictdf['Month of Transfer']=hpp2022dictdf['Month of Transfer'].replace(5,"May")

unique_sold_first_postcodes=list(hpp2022dictdf["First Postcode"].unique())

print("\nthere are",len(unique_sold_first_postcodes),"postcodes in UK that had a house sale in 2022\n")

singlesalepostcodes=hpp2022dictdf[hpp2022dictdf.groupby('First Postcode')['Price'].transform('size') == 1]
print("\nthere were",len(singlesalepostcodes["First Postcode"].unique()),"postcodes with a single sale in 2022\n")

hpp2022dictdf=hpp2022dictdf[hpp2022dictdf.groupby('First Postcode')['Price'].transform('size') > 1]
print("\nthere were",len(hpp2022dictdf["First Postcode"].unique()),"postcodes more than a single sale in 2022\n")

hpp2022dictdf["Price"]=hpp2022dictdf["Price"].astype(str)
hpp2022dictdfgrouped=hpp2022dictdf.groupby(['First Postcode'])['Price'].apply(','.join).reset_index()
hpp2022dictdfgrouped.head()
hpp2022dictdfgrouped.rename(columns={"Price":"All Prices for First Postcode"},inplace=True)
hpp2022dictdfgrouped.drop_duplicates(subset=["First Postcode"],inplace=True)
hpp2022dictdfgrouped.reset_index(inplace=True,drop=True)
print("house prices grouped by postcode has",hpp2022dictdfgrouped.shape[0],"rows")
#print("hpp2022dictdfgrouped=")
#hpp2022dictdfgrouped.head()


postcodes_with_train_times_df.head()
print("Train times for each postcode loaded and postcode split")

print("merging train time df with house prices grouped by first postcode...")
finaldf=pd.merge(hpp2022dictdfgrouped,postcodes_with_train_times_df[["First Postcode","train time to work"]],on="First Postcode")
print("Done")
finaldf.head(20)
finaldf["train time to work"]=finaldf["train time to work"].astype(str)
print("Joining finaldf train times into a single comma seperated string...")
commutedf=finaldf.groupby("First Postcode")['train time to work'].apply(','.join).reset_index()
commutedf.set_index("First Postcode",inplace=True)
print("Done")
print("merging finaldf with commuter df ...")
commutedf=pd.merge(finaldf,commutedf,on="First Postcode")
print("Done")
commutedf.drop(columns="train time to work_x",inplace=True)
commutedf.rename(columns={"train time to work_y":"train time to work"},inplace=True)
commutedf.drop_duplicates("First Postcode",inplace=True)
commutedf.head(20)
commutedf.set_index("First Postcode",inplace=True)
print("putting commutedf into a dictionary...")
commutedict=commutedf.to_dict(orient="index")
print("Done")
#print(commutedict)
hpp2022dictdfgrouped.head()

print("calculating the median prices and median times for each postcode")
for postcode,data in commutedict.items():
    data=commutedict.get(postcode)
    prices=data.get("All Prices for First Postcode").split(",")
    prices=[float(price) for price in prices]
    times=data.get("train time to work").split(",")
    times=[float(time) for time in times]
    mediantime=round(statistics.median(times))
    medianprice=round(statistics.median(prices))
    commutedict[postcode]['Median Price']=medianprice
    commutedict[postcode]['Median Time']=mediantime
print("Done")
print("putting the last df into a df to adjust index and drop columns")
lastdf=pd.DataFrame.from_dict(commutedict,orient="index")
lastdf.reset_index(inplace=True)
lastdf=lastdf[["index","Median Price","Median Time"]]
lastdf.set_index("index",inplace=True)
#print("lastdf")
lastdf.head(20)
print("Done")
print("putting the last df back into a dict as the last step")
lastdfdict=lastdf.to_dict(orient="index")
print("Lastdf written to dict")
print("lastdfdict = E10")
lastdfdict.get("E10")

# validated until here

postcodemappings.reset_index(inplace=True)
postcodemappings.set_index("index",inplace=True)
print("postcode df being written to df")
dict0=postcodemappings.to_dict(orient="index")
postcodeladict={}
print("postcode df dict being split to get first postcode")
for i in range(1,len(dict0.keys())):
    vals=list(dict0.get(i).values())
    #print(vals)
    PC=vals[1],"Local authority= ",vals[6],"first postcode=",vals[1].split(" ")[0]
    LAV=vals[6]
    FPC=vals[1].split(" ")[0]
    postcodeladict[FPC]=LAV
print("postcodeladict for E10")
postcodeladict.get("E10")

# OK UNTIL HERE

print("getting local authority for first postcode")
for postcode in list(lastdfdict.keys()):
    try:
        localauthority=postcodeladict[postcode]
        lastdfdict[postcode]["local authority"]=localauthority
    except:
        lastdfdict[postcode]["local authority"]="LA not known"
print("local authority in lastdfdict for E10...")
lastdfdict["E10"]

print("getting population for local authority")

for postcode in list(lastdfdict.keys()):
    try:
        localauthority=lastdfdict.get(postcode)["local authority"]
        population=list(population_infodict[localauthority].values())[0]
        lastdfdict[postcode]["Population"]=population
    except:
        lastdfdict[postcode]["Population"]="Population not known"
print("lastdfdict for E10 including population")
lastdfdict["E10"]


print("getting deprivation rank for local authority")

deprivation_scores_grouped=deprivation_scores.groupby('Local Authority Name')[["Index of Multiple Deprivation (IMD) Rank"]].median()
#deprivation_scores_grouped.loc["ISLE OF ANGLESEY"][0]
alldepscores=[]
for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        deprivationscore=deprivation_scores_grouped.loc[localauthority][0]
        alldepscores.append(deprivationscore)
        lastdfdict[postcode]["Deprivation Rank"]=deprivationscore
    except:
        lastdfdict[postcode]["Deprivation Rank"]="Deprivation Unknown"
lastdfdict["E10"]





# OK UNTIL HERE #






print("getting median price for area relative to national median price")

allprices=[]
for postcode in list(lastdfdict.keys()):
    allprices.append(lastdfdict[postcode]["Median Price"])
allmedianprice=statistics.median(allprices)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Postcode Median Price Relative to National Median Price"]=lastdfdict[postcode]["Median Price"]/allmedianprice
lastdfdict["E10"]

print("getting median time for area relative to national median time")

alltimes=[]
for postcode in list(lastdfdict.keys()):
    alltimes.append(lastdfdict[postcode]["Median Time"])
allmediantime=statistics.median(alltimes)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Postcode Median Time Relative to National Median Time"]=lastdfdict[postcode]["Median Time"]/allmediantime
lastdfdict["E10"]


print("getting retail counts for each local authority")

for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        retaildict=retail_infodict.get(localauthority)
        retailcount=list(retaildict.values())[0]
        lastdfdict[postcode]["Retail Count"]=retailcount
    except:
        lastdfdict[postcode]["Retail Count"]="Retail Count Unknown"
lastdfdict["E10"]



#print("getting crime counts for local authority")
#
#for postcode in list(lastdfdict.keys()):
#    localauthority=lastdfdict[postcode]["local authority"]
#    try:
#        crimecount=list(crimedfdict.get(localauthority).values())[0]
#        lastdfdict[postcode]["Crime Count"]=crimecount
#    except:
#        lastdfdict[postcode]["Crime Count"]="Crime Count Unknown"
#lastdfdict["E10"]


print("getting area for local authority")

for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        area=list(areasizeinfodict.get(localauthority).values())[0]
        lastdfdict[postcode]["Area"]=area
    except:
        lastdfdict[postcode]["Area"]="Area Unknown"
lastdfdict["E10"]

print("area calculations done")


maxbeachcount=max(list(beachcountdict.values()))

postcodeswithoutbeaches=[]

print("getting beach count for first postcodes")

for postcode in list(lastdfdict.keys()):
    try:
        postcodestem=re.sub(r'\d+', '', postcode)
        beachcount=beachcountdict[postcodestem]
        lastdfdict[postcode]["Beach Count"]=beachcount
        lastdfdict[postcode]["Beach Score (Relative to Max)"]=beachcount/maxbeachcount
    except:
        postcodeswithoutbeaches.append(postcode)
        lastdfdict[postcode]["Beach Count"]=0
        lastdfdict[postcode]["Beach Score (Relative to Max)"]=0
lastdfdict["E10"]

print("Beach count done")

#OK UNTIL HERE




print("getting postcodes with any unknown values")


unknowndict={}
for postcode in list(lastdfdict.keys()):
    lanacount = 0
    if (lastdfdict[postcode]["local authority"]=="LA not known"):
        lanacount += 1
    popnacount = 0
    if (lastdfdict[postcode]["Population"]=="Population not known"):
        popnacount += 1
    dinacount = 0
    if (lastdfdict[postcode]["Deprivation Rank"]=="Deprivation Unknown"):
        dinacount += 1
    areanacount=0
    if (lastdfdict[postcode]["Area"]=="Area Unknown"):
        areanacount += 1
#    ccnacount = 0
#    if (lastdfdict[postcode]["Crime Count"]=="Crime Count Unknown"):
#        ccnacount += 1
    retailnacount = 0
    if (lastdfdict[postcode]["Retail Count"]=="Retail Count Unknown"):
        retailnacount += 1
    if sum([lanacount,popnacount,dinacount,areanacount,retailnacount])>0:
        unknowndict[postcode]={"LA Unknown":lanacount,"Pop Unknown":popnacount,"DepInd Unknown":dinacount,"Area Unknown":areanacount,"Retail Unknown":retailnacount}
postcodes_to_drop=list(unknowndict.keys())
print(len(postcodes_to_drop))
print("dropping any postcodes from lastdfdict with any NA values")
print("this is len of lastdfdict before dropping",len(lastdfdict))
for postcode in list(lastdfdict.keys()):
    if postcode in postcodes_to_drop:
        del lastdfdict[postcode]
print("this is len of lastdfdict after dropping",len(lastdfdict))


#Deprivation Rank compared to mean 

mediandepscore=statistics.median(alldepscores)
print(mediandepscore)
for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    depscore=deprivation_scores_grouped.loc[localauthority][0]
    relativedepscore=depscore/mediandepscore
    lastdfdict[postcode]["Deprivation Score Relative to National Median"]=relativedepscore
lastdfdict["E10"]

popdensitylist=[]
for postcode in list(lastdfdict.keys()):
    popdensity=lastdfdict[postcode]["Population"]/lastdfdict[postcode]["Area"]
    lastdfdict[postcode]["Population Density"]=popdensity
    popdensitylist.append(popdensity)

medianpopdensity=statistics.median(popdensitylist)    
for postcode in list(lastdfdict.keys()):
    relativepopdensity=lastdfdict[postcode]["Population Density"]/medianpopdensity
    lastdfdict[postcode]["Population Density (Relative to Median)"]=relativepopdensity

# Total crimes per 1000 pop

#for postcode in list(lastdfdict.keys()):
#    relativecrimescore=lastdfdict[postcode]['Crime Count']/lastdfdict[postcode]['Population']
#    lastdfdict[postcode]["Crimes per 1000"]=relativecrimescore
#lastdfdict["E10"]

# LocAuth Crime rate compared to median Crime rate

#allcrimerates=[]
#for postcode in list(lastdfdict.keys()):
#    allcrimerates.append(lastdfdict[postcode]["Crimes per 1000"])
#allmediancrimes=statistics.median(allcrimerates)
#for postcode in list(lastdfdict.keys()):
#    lastdfdict[postcode]["Crime rate relative to National Median"]=lastdfdict[postcode]["Crimes per 1000"]/allmediancrimes
#lastdfdict["E10"]


#Retail Businesses per Hectare

for postcode in list(lastdfdict.keys()):
    retailperhectare=lastdfdict[postcode]['Retail Count']/lastdfdict[postcode]['Area']
    lastdfdict[postcode]["Businesses per Hectere"]=retailperhectare
lastdfdict["E10"]

# LocAuth retail density compared to Median retail density

allretaildensity=[]
for postcode in list(lastdfdict.keys()):
    allretaildensity.append(lastdfdict[postcode]["Businesses per Hectere"])
allmedianretaildensity=statistics.median(allretaildensity)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Retail Score Relative to National Median"]=lastdfdict[postcode]["Businesses per Hectere"]/allmedianretaildensity
lastdfdict["E10"]

print("all done!")
# Out:
# shape of input df is (105501, 16)
#
# this is the breakdown by house type across all UK
#  Terraced         32859
# Semi-Detached    28638
# Detached         21687
# Flat             18063
# Other             4254
# Name: Property Type, dtype: int64
#
#  houses sold since 2022
#  (18063, 16)
# C:\Users\Carl\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# hpp2022dict[2]= {'Transaction unique identifier': '{DE2D0CDF-7F05-51EE-E053-6C04A8C00671}', 'Price': 370000, 'Date of Transfer': '2022-03-31 00:00', 'Postcode': 'EX8 1BG', 'Property Type': 'Flat', 'Old/New': 'N', 'Duration': 'L', 'PAON': '17', 'SAON': 'FLAT 1', 'Street': 'MORTON CRESCENT', 'Locality': nan, 'Town/City': 'EXMOUTH', 'District': 'EAST DEVON', 'County': 'DEVON', 'PPD Category Type': 'A', 'TBD': 'A'}
#
# House price dictionary since 2022 has 18056 keys
#
#
# House price dictionary df (with split postcode) since 2022 has 18056 rows
#
# there are 1885 postcodes in UK that had a house sale in 2022
#
#
# there were 245 postcodes with a single sale in 2022
#
#
# there were 1640 postcodes more than a single sale in 2022
#
# house prices grouped by postcode has 1640 rows
# Train times for each postcode loaded and postcode split
# merging train time df with house prices grouped by first postcode...
# Done
# Joining finaldf train times into a single comma seperated string...
# Done
# merging finaldf with commuter df ...
# Done
# putting commutedf into a dictionary...
# Done
# calculating the median prices and median times for each postcode
# Done
# putting the last df into a df to adjust index and drop columns
# Done
# putting the last df back into a dict as the last step
# Lastdf written to dict
# lastdfdict = E10
# postcode df being written to df
# postcode df dict being split to get first postcode
# postcodeladict for E10
# getting local authority for first postcode
# local authority in lastdfdict for E10...
# getting population for local authority
# lastdfdict for E10 including population
# getting deprivation rank for local authority
# getting median price for area relative to national median price
# getting median time for area relative to national median time
# getting retail counts for each local authority
# getting area for local authority
# area calculations done
# getting beach count for first postcodes
# Beach count done
# getting postcodes with any unknown values
# 112
# dropping any postcodes from lastdfdict with any NA values
# this is len of lastdfdict before dropping 1035
# this is len of lastdfdict after dropping 923
# 17282.0
# all done!

# %%
lastdfdict["E10"]
# Out:
# {'Median Price': 370000,
#  'Median Time': 34,
#  'local authority': 'WALTHAM FOREST',
#  'Population': 278400,
#  'Deprivation Rank': 11134.0,
#  'Postcode Median Price Relative to National Median Price': 2.1771109149749925,
#  'Postcode Median Time Relative to National Median Time': 0.265625,
#  'Retail Count': 1360.0,
#  'Area': 3881.02,
#  'Beach Count': 0,
#  'Beach Score (Relative to Max)': 0,
#  'Deprivation Score Relative to National Median': 0.6442541372526328,
#  'Population Density': 71.73371948611448,
#  'Population Density (Relative to Median)': 6.792846744540011,
#  'Businesses per Hectere': 0.3504233423172259,
#  'Retail Score Relative to National Median': 12.014271030256518}

# %%
lastdfdict={key:val for key,val in lastdfdict.items() if 400000<lastdfdict[key]["Median Price"]<550000}

# %%
lastdfdict.keys()

# %%
maxmedprice=0
for postcode in list(lastdfdict.keys()):
    medprice=lastdfdict[postcode]["Median Price"]
    if medprice>maxmedprice:
        maxmedprice=medprice
print("maxprice",maxmedprice)
maxbusinesses=0
for postcode in list(lastdfdict.keys()):
    businessdens=lastdfdict[postcode]["Businesses per Hectere"]
    if businessdens>maxbusinesses:
        maxbusinesses=businessdens
print("maxbusinesses",maxbusinesses)
maxdeprank=0
for postcode in list(lastdfdict.keys()):
    deprank=lastdfdict[postcode]["Deprivation Rank"]
    if deprank>maxdeprank:
        maxdeprank=deprank
print("maxdep",maxdeprank)
#maxcrimerank=0
#for postcode in list(lastdfdict.keys()):
#    crimerank=lastdfdict[postcode]["Crimes per 1000"]
#    if crimerank>maxcrimerank:
#        maxcrimerank=crimerank
#print("maxcrime",maxcrimerank)
maxtimerank=0
for postcode in list(lastdfdict.keys()):
    timerank=lastdfdict[postcode]["Median Time"]
    if timerank>maxtimerank:
        maxtimerank=timerank
print("maxtime",maxtimerank)


maxpopdens=0
for postcode in list(lastdfdict.keys()):
    popdens=lastdfdict[postcode]["Population Density"]
    if popdens>maxpopdens:
        maxpopdens=popdens
print("maxpopdens",maxpopdens)
# Out:
# maxprice 1095000
# maxbusinesses 2.2880386424304056
# maxdep 30960.0
# maxtime 595
# maxpopdens 145.78103231277638

# %%
for postcode in list(lastdfdict.keys()):
    price_score=(lastdfdict[postcode]['Median Price']/maxmedprice)**2
    lastdfdict[postcode]["Price Score (Relative to Max)"]=price_score
    # smaller is better
    retail_score=(lastdfdict[postcode]["Businesses per Hectere"]/maxbusinesses)
    lastdfdict[postcode]["Retail Score (Relative to Max)"]=retail_score
    # bigger is better
    deprivation_score=(lastdfdict[postcode]["Deprivation Rank"]/maxdeprank)**2
    lastdfdict[postcode]["Deprivation Score (Relative to Max)"]=deprivation_score
    # bigger is better
    #crime_score=(lastdfdict[postcode]["Crimes per 1000"]/maxcrimerank)**1.25
    # smaller is better
    time_score=(lastdfdict[postcode]["Median Time"]/maxtimerank)
    lastdfdict[postcode]["Time Score (Relative to Max)"]=time_score
    
    #smaller is better
    population_density_score=(lastdfdict[postcode]["Population Density"]/maxpopdens)
    lastdfdict[postcode]["Population Density (Relative to Max)"]=population_density_score
    
    beach_score=lastdfdict[postcode]["Beach Score (Relative to Max)"]
    
    # smaller is better
    #lastdfdict[postcode]["Total Score (Postcode)"]=(deprivation_score*retail_score*beach_score)/(price_score)
    # bigger is better
outputdf=pd.DataFrame.from_dict(data=lastdfdict,orient="index")
enggreendf=enggreendf.reset_index()
enggreendf=enggreendf.rename(columns={"Local Authority":"local authority"})
outputdf=outputdf[["local authority","Median Price","Price Score (Relative to Max)","Median Time","Time Score (Relative to Max)","Retail Count","Population","Area","Population Density","Businesses per Hectere","Retail Score (Relative to Max)","Deprivation Rank","Deprivation Score (Relative to Max)","Beach Count","Beach Score (Relative to Max)"]]
outputdf=outputdf.reset_index()
#outputdf.head()
outputdf=outputdf.rename(columns={"index":"Postcode"})
finaldf=pd.merge(outputdf,enggreendf,on="local authority")
##finaldf=finaldf.rename(columns={"index":"Postcode"})
#finaldf=finaldf.reset_index()
finaldf.head()
finaldf=finaldf.set_index("Postcode")
finaldf["Total Score (Postcode)"]=(finaldf["Deprivation Score (Relative to Max)"]*finaldf["Retail Score (Relative to Max)"]*finaldf["Beach Score (Relative to Max)"]*finaldf["Green Score (Relative to Max)"])/(finaldf["Price Score (Relative to Max)"])
savedf=finaldf.sort_values(by="Total Score (Postcode)",ascending=False)
savedf.to_excel("flats_within_england.xlsx")

# %%
savedf.sort_values(by="Total Score (Postcode)",ascending=False)
# Out:
#                        local authority  Median Price  \
# Postcode
# NE32                    SOUTH TYNESIDE         75000
# NE1                NEWCASTLE UPON TYNE        150000
# BN41                 BRIGHTON AND HOVE        260000
# NE10                         GATESHEAD         82500
# EX4                             EXETER        156500
# BN2                  BRIGHTON AND HOVE        275000
# NE11                         GATESHEAD         85000
# BN1                  BRIGHTON AND HOVE        285000
# TS18                  STOCKTON-ON-TEES         58500
# NE21                         GATESHEAD         88975
# EX2                             EXETER        171500
# EX1                             EXETER        176725
# BN3                  BRIGHTON AND HOVE        327500
# NW1                        WESTMINSTER        690000
# PR7                            CHORLEY        105000
# TS17                  STOCKTON-ON-TEES         72000
# NR1                            NORWICH        150000
# PL4                           PLYMOUTH        109000
# PO3                         PORTSMOUTH        153750
# PL5                           PLYMOUTH        109500
# CH63                            WIRRAL         89500
# PL2                           PLYMOUTH        112500
# CH42                            WIRRAL         91000
# TS16                  STOCKTON-ON-TEES         82500
# PO1                         PORTSMOUTH        162500
# TN37                          HASTINGS        163500
# TN34                          HASTINGS        165000
# PO5                         PORTSMOUTH        165000
# TN35                          HASTINGS        166975
# PL1                           PLYMOUTH        120000
# IP2                            IPSWICH        123000
# PO14                           FAREHAM        122998
# PO6                         PORTSMOUTH        177000
# PR4                       SOUTH RIBBLE         69950
# IP3                            IPSWICH        129000
# SO19                       SOUTHAMPTON        140000
# BN22                        EASTBOURNE        155000
# CH46                            WIRRAL        107500
# SO17                       SOUTHAMPTON        142500
# CH41                            WIRRAL        107816
# SO18                       SOUTHAMPTON        143000
# CT9                             THANET        135000
# TN38                          HASTINGS        199538
# SO30                         EASTLEIGH        187500
# PO16                           FAREHAM        144000
# SO53                         EASTLEIGH        194000
# CH43                            WIRRAL        121000
# TQ4                             TORBAY        146000
# CH62                            WIRRAL        122500
# YO26                              YORK        160000
# CT11                            THANET        149995
# SO15                       SOUTHAMPTON        165500
# N11                             BARNET        313500
# SO14                       SOUTHAMPTON        169000
# CH47                            WIRRAL        128500
# CT12                            THANET        156750
# BN21                        EASTBOURNE        192500
# PO36                     ISLE OF WIGHT        124250
# BN14                          WORTHING        197500
# PO33                     ISLE OF WIGHT        132500
# LN5                            LINCOLN         90625
# PO22                              ARUN        134250
# CT7                             THANET        188000
# PO37                     ISLE OF WIGHT        142500
# LA14                 BARROW-IN-FURNESS         87000
# CH65         CHESHIRE WEST AND CHESTER         81000
# PR5                       SOUTH RIBBLE        107750
# CH45                            WIRRAL        158250
# TS10              REDCAR AND CLEVELAND         56950
# TQ2                             TORBAY        191750
# PR25                      SOUTH RIBBLE        110000
# TS15                  STOCKTON-ON-TEES        145000
# BN11                          WORTHING        225000
# YO7                          HARROGATE        120000
# NW5                             CAMDEN        557500
# EX7                        TEIGNBRIDGE        136975
# YO24                              YORK        220998
# PO21                              ARUN        148250
# TQ12                       TEIGNBRIDGE        143500
# SS7                       CASTLE POINT        230000
# SW20                            MERTON        366250
# PO9                             HAVANT        125000
# CT10                            THANET        225000
# SW14              RICHMOND UPON THAMES        451500
# SS1                    SOUTHEND-ON-SEA        185000
# N17                           HARINGEY        310000
# SR1                         SUNDERLAND         75000
# SS11                        CHELMSFORD        215000
# CT6                         CANTERBURY        174998
# SS16                          BASILDON        172500
# EX14                        EAST DEVON        132250
# LA15                 BARROW-IN-FURNESS        110500
# CH66         CHESHIRE WEST AND CHESTER        102500
# YO14                       SCARBOROUGH         70000
# N15                           HARINGEY        325000
# NW2                             BARNET        355988
# CT2                         CANTERBURY        180000
# TQ14                       TEIGNBRIDGE        169950
# L20                             SEFTON         65000
# SS0                    SOUTHEND-ON-SEA        205000
# SS2                    SOUTHEND-ON-SEA        205000
# SW19                            MERTON        444500
# CO1                         COLCHESTER        153750
# TS7                      MIDDLESBROUGH         70500
# NW4                             BARNET        395000
# TN11             TONBRIDGE AND MALLING        210000
# BN15                              ADUR        177500
# BN12                          WORTHING        312500
# SS3                    SOUTHEND-ON-SEA        220000
# CA1                           CARLISLE         64000
# TN9              TONBRIDGE AND MALLING        215000
# GL51                        CHELTENHAM        161500
# CT1                         CANTERBURY        208000
# N22                           HARINGEY        380000
# GU11                          RUSHMOOR        153000
# CT8                             THANET        292500
# SS15                          BASILDON        211000
# CH48                            WIRRAL        242500
# NG4                            GEDLING        106000
# N4                           ISLINGTON        435000
# CO5                         COLCHESTER        170000
# CH3          CHESHIRE WEST AND CHESTER        126750
# LA3                          LANCASTER         73000
# PR8                             SEFTON        111000
# NW7                             BARNET        445000
# SW13              RICHMOND UPON THAMES        615000
# FY6                               WYRE        104000
# CO2                         COLCHESTER        177500
# SR5                         SUNDERLAND        100000
# N8                            HARINGEY        420000
# TN27                         MAIDSTONE        222500
# LN1                            LINCOLN        162000
# N9                             ENFIELD        215000
# TS24                        HARTLEPOOL         54000
# CT17                             DOVER        128000
# SS9                    SOUTHEND-ON-SEA        264000
# GU21                            WOKING        242500
# BS35             SOUTH GLOUCESTERSHIRE        126500
# CH2          CHESHIRE WEST AND CHESTER        140000
# SW15                        WANDSWORTH        497500
# EX8                         EAST DEVON        185000
# PR9                             SEFTON        125000
# N19                          ISLINGTON        499725
# L31                             SEFTON         88750
# BN42                              ADUR        223000
# SW18                        WANDSWORTH        514250
# PE7                    HUNTINGDONSHIRE        126500
# NW3                             CAMDEN        972500
# EX5                         EAST DEVON        196500
# GU22                            WOKING        267500
# BS34             SOUTH GLOUCESTERSHIRE        140250
# BN17                              ARUN        177000
# CT5                         CANTERBURY        270000
# N18                            ENFIELD        244500
# EX17                         MID DEVON         88940
# L9                           LIVERPOOL         75250
# ME17                         MAIDSTONE        163000
# TS25                        HARTLEPOOL         63950
# LA4                          LANCASTER         95000
# NE23                    NORTHUMBERLAND         71000
# FY1                          BLACKPOOL         54750
# CH1          CHESHIRE WEST AND CHESTER        169000
# PO19                        CHICHESTER        219500
# BN43                              ADUR        258500
# PR1                            PRESTON        100000
# PO10                            HAVANT        235000
# N5                           ISLINGTON        590000
# N1                           ISLINGTON        590000
# GU12                         GUILDFORD        194750
# L25                          LIVERPOOL         80000
# BH25                        NEW FOREST        235000
# PE21                            BOSTON         92500
# L22                             SEFTON        106250
# NG14                           GEDLING        147657
# SW12                        WANDSWORTH        612500
# TN12             TONBRIDGE AND MALLING        320000
# GU14                          RUSHMOOR        223000
# GL1                         GLOUCESTER        125000
# SW16                           LAMBETH        390000
# YO11                       SCARBOROUGH        123750
# ME16                         MAIDSTONE        182500
# SO50                        WINCHESTER        167000
# CA14                         ALLERDALE         59500
# SW11                        WANDSWORTH        640000
# SW5             KENSINGTON AND CHELSEA       1095000
# TN15                         SEVENOAKS        187000
# LS25                             LEEDS        110500
# PE1                       PETERBOROUGH        118500
# GU10                         GUILDFORD        211000
# NG17                          ASHFIELD         82500
# PO18                        CHICHESTER        246000
# CA8                           CARLISLE        103500
# PE29                   HUNTINGDONSHIRE        165000
# NE42                    NORTHUMBERLAND         82500
# ME20             TONBRIDGE AND MALLING        215000
# L8                           LIVERPOOL         90000
# LS27                             LEEDS        116250
# ME14                         MAIDSTONE        195000
# LA10                    SOUTH LAKELAND        112000
# PL21                        SOUTH HAMS        136500
# TR15                          CORNWALL        101500
# YO12                       SCARBOROUGH        135000
# NR28                     NORTH NORFOLK        141000
# ME7                             MEDWAY        135000
# LA1                          LANCASTER        115000
# LS15                             LEEDS        120000
# BS22                    NORTH SOMERSET        146000
# SS17                          THURROCK        200000
# PE19                   HUNTINGDONSHIRE        172500
# FY8                              FYLDE        141500
# LS13                             LEEDS        122000
# ME6              TONBRIDGE AND MALLING        226500
# YO25          EAST RIDING OF YORKSHIRE         91250
# BN26                           WEALDEN        185000
# NR30                    GREAT YARMOUTH         76500
# BS37             SOUTH GLOUCESTERSHIRE        190000
# TN23                           ASHFORD        175000
# N16                            HACKNEY        500000
# L13                          LIVERPOOL         98125
# ME1              TONBRIDGE AND MALLING        236000
# YO15          EAST RIDING OF YORKSHIRE         94950
# TN8                          SEVENOAKS        218500
# GU51                              HART        210000
# GU47                  BRACKNELL FOREST        245000
# LS28                             LEEDS        130750
# SR6                         SUNDERLAND        165000
# NG10                           EREWASH        128000
# SW2                            LAMBETH        475000
# NG9                           BROXTOWE         96000
# SW8                            LAMBETH        475750
# CT14                             DOVER        205000
# ME18                         MAIDSTONE        222000
# BN24                           WEALDEN        200000
# BS48                    NORTH SOMERSET        163750
# L2                           LIVERPOOL        105000
# BS23                    NORTH SOMERSET        165000
# PE9                       PETERBOROUGH        146000
# SW9                            LAMBETH        495000
# SO21                        WINCHESTER        210000
# CT15                             DOVER        212500
# LA9                     SOUTH LAKELAND        133500
# L23                             SEFTON        142750
# SR7                      COUNTY DURHAM         51248
# L7                           LIVERPOOL        108500
# TR14                          CORNWALL        122500
# EX31                       NORTH DEVON        152500
# GU24                         GUILDFORD        275000
# YO8                              SELBY         98000
# OX7                   WEST OXFORDSHIRE        152500
# GU1                          GUILDFORD        277500
# ME2                             MEDWAY        165000
# ME19             TONBRIDGE AND MALLING        272000
# L5                           LIVERPOOL        114025
# N21                            ENFIELD        387500
# SW4                            LAMBETH        536250
# GU4                          GUILDFORD        282000
# EX16                         MID DEVON        137500
# NE46                    NORTHUMBERLAND        106000
# FY4                          BLACKPOOL         82000
# PL12                          CORNWALL        115000
# CH64         CHESHIRE WEST AND CHESTER        251750
# CA7                          ALLERDALE         82000
# TN25                           ASHFORD        210000
# BN16                              ARUN        288000
# GU17                              HART        245000
# CO10                           BABERGH        162500
# ME3                             MEDWAY        172500
# DN12                         DONCASTER         64500
# LS20                             LEEDS        155000
# SS4                           ROCHFORD        184000
# LA11                    SOUTH LAKELAND        150000
# NW10                             BRENT        370000
# LA6                          LANCASTER        150000
# N13                            ENFIELD        410000
# TS12              REDCAR AND CLEVELAND        182500
# DN17                NORTH LINCOLNSHIRE         60000
# SO31                           FAREHAM        196500
# TR9                           CORNWALL        137000
# OX16                          CHERWELL        146000
# NR13                         BROADLAND        155750
# LS16                             LEEDS        160000
# TN2                    TUNBRIDGE WELLS        236000
# PL14                          CORNWALL        122500
# SS6                           ROCHFORD        190000
# GU15                      SURREY HEATH        238500
# FY2                          BLACKPOOL         90000
# NR27                     NORTH NORFOLK        194750
# L19                          LIVERPOOL        127500
# L1                           LIVERPOOL        127500
# ME4                             MEDWAY        185750
# NG15                          ASHFIELD        121000
# BN9                              LEWES        170000
# CT13                             DOVER        258500
# LS1                              LEEDS        167000
# NG12                        RUSHCLIFFE        110000
# TN1                    TUNBRIDGE WELLS        247500
# NE66                    NORTHUMBERLAND        120000
# ME8                             MEDWAY        191250
# NG18                         MANSFIELD         96475
# NR26                     NORTH NORFOLK        202500
# TR10                          CORNWALL        150000
# GU16                      SURREY HEATH        253500
# L32                           KNOWSLEY         72500
# NR31                    GREAT YARMOUTH        107500
# TN14                         SEVENOAKS        297500
# BN18                              ARUN        337500
# SO23                        WINCHESTER        271250
# NR12                     NORTH NORFOLK        210000
# GU3                          GUILDFORD        344000
# SW6             HAMMERSMITH AND FULHAM        550000
# L37                             SEFTON        188250
# L36                           KNOWSLEY         77250
# TN22                           WEALDEN        215000
# LA5                          LANCASTER        182000
# NE20                    NORTHUMBERLAND        135875
# L34                           KNOWSLEY         80000
# TQ9                         SOUTH HAMS        207000
# L17                          LIVERPOOL        151500
# GU9                           WAVERLEY        242000
# PL26                          CORNWALL        151250
# NE61                    NORTHUMBERLAND        141500
# BN25                             LEWES        206250
# DN8                          DONCASTER         85000
# NG6                         NOTTINGHAM        102000
# OX1                             OXFORD        377500
# TN13                         SEVENOAKS        350000
# OX29                  WEST OXFORDSHIRE        217500
# TR1                           CORNWALL        180000
# L39                    WEST LANCASHIRE        114750
# IP22                     SOUTH NORFOLK         97500
# TR18                          CORNWALL        182000
# BN6                         MID SUSSEX        310000
# CA4                           CARLISLE        195000
# NW6                              BRENT        510750
# GU25                         RUNNYMEDE        292714
# OX5                           CHERWELL        200000
# GU7                           WAVERLEY        270000
# TN3                            WEALDEN        250225
# IP6                        MID SUFFOLK        133500
# DN15                NORTH LINCOLNSHIRE         85000
# SO51                       TEST VALLEY        190000
# LA23                    SOUTH LAKELAND        215000
# L18                          LIVERPOOL        175000
# DN3                          DONCASTER         95000
# GU33                    EAST HAMPSHIRE        155000
# SO40                        NEW FOREST        175000
# TA18                    SOUTH SOMERSET        133000
# L3                           LIVERPOOL        180000
# GU34                    EAST HAMPSHIRE        158750
# OX26                          CHERWELL        217000
# L40                    WEST LANCASHIRE        131000
# CO6                          BRAINTREE        143098
# TN6                            WEALDEN        275000
# LS17                         HARROGATE        150500
# IP14                       MID SUFFOLK        148750
# NG24               NEWARK AND SHERWOOD         90000
# PL13                          CORNWALL        190000
# ME9                              SWALE        154500
# ME10                             SWALE        155000
# GL11                            STROUD        116750
# TR27                          CORNWALL        222500
# GU8                           WAVERLEY        318000
# IP30                           BABERGH        173750
# BN7                              LEWES        266500
# PL25                          CORNWALL        200000
# TR3                           CORNWALL        232500
# CA11                              EDEN        140000
# ME13                             SWALE        172500
# TA6                          SEDGEMOOR        119995
# NG31                    SOUTH KESTEVEN         93750
# TR11                          CORNWALL        260000
# DN22                         BASSETLAW         90000
# GL5                             STROUD        141000
# TR7                           CORNWALL        270000
# ME12                             SWALE        195000
# PE25                      EAST LINDSEY         82000
# NG11                        NOTTINGHAM        160000
# TN5                            WEALDEN        370500
# NG2                         NOTTINGHAM        165000
# OX14               VALE OF WHITE HORSE        189000
# HU15          EAST RIDING OF YORKSHIRE        112500
# OX11               VALE OF WHITE HORSE        196000
# TN31                            ROTHER        155000
# CO12                          TENDRING        121500
# GL10                            STROUD        162000
# SO41                        NEW FOREST        268500
# PE15                           FENLAND        102500
# IP27                         BRECKLAND         99975
# HU17          EAST RIDING OF YORKSHIRE        121250
# HU16          EAST RIDING OF YORKSHIRE        121500
# OX10                 SOUTH OXFORDSHIRE        253750
# GL7                           COTSWOLD        190000
# CO15                          TENDRING        135000
# DN35           NORTH EAST LINCOLNSHIRE        142500
# TN40                            ROTHER        176500
# DN14          EAST RIDING OF YORKSHIRE        112500
# TN32                            ROTHER        191500
# IP24                         BRECKLAND        121250
# DN21                      WEST LINDSEY         99500
# NE65                    NORTHUMBERLAND        326500
# GU30                    EAST HAMPSHIRE        315000
# TN33                            ROTHER        206975
# PE11                     SOUTH HOLLAND        118000
# YO21                         HAMBLETON        194000
# TR26                          CORNWALL        410000
# CO14                          TENDRING        166250
# LS29                          BRADFORD        197500
# GU27                        CHICHESTER        190000
# TD15                    NORTHUMBERLAND         83000
# TN39                            ROTHER        235000
# GL56                          COTSWOLD        261500
# CO7                           TENDRING        187500
# LN4                     NORTH KESTEVEN        123500
# GL20                        TEWKESBURY        143000
# CO16                          TENDRING        206000
# YO17                           RYEDALE        170000
# OX2                VALE OF WHITE HORSE        340000
# LN6                     NORTH KESTEVEN        137500
# CO13                          TENDRING        225950
# GU5                           WAVERLEY        841250
# CA28                          COPELAND         86975
# NG34                    NORTH KESTEVEN         89000
# BN8                              LEWES        715000
# CO11                          TENDRING        258750
# LS24                             SELBY        150000
# SN15                         WILTSHIRE        153750
# BL6                             BOLTON         85000
# SN8                          WILTSHIRE        168500
# SP11                         WILTSHIRE        162500
# ST7                      CHESHIRE EAST        154542
# SK9                      CHESHIRE EAST        195000
# KT12                         ELMBRIDGE        275000
# SY13                     CHESHIRE EAST        100000
# LE12                        RUSHCLIFFE        153350
# KT10                         ELMBRIDGE        248750
# KT11                         ELMBRIDGE        530000
# BA15                         WILTSHIRE        185000
# SN12                         WILTSHIRE        125000
# BA1       BATH AND NORTH EAST SOMERSET        305000
# BA14                         WILTSHIRE        142000
# BA13                         WILTSHIRE        136500
# SP2                          WILTSHIRE        176500
# BA12                         WILTSHIRE        127950
# BA2       BATH AND NORTH EAST SOMERSET        247500
# KT7                          ELMBRIDGE        365000
# B97                           REDDITCH        131500
# CV37                 STRATFORD-ON-AVON        160000
# CV35                 STRATFORD-ON-AVON        203000
# B95                  STRATFORD-ON-AVON        140000
# B79                           TAMWORTH        104500
# BA11                            MENDIP        165000
# BA21                    SOUTH SOMERSET        131000
# BA22                    SOUTH SOMERSET        127500
# AL2                          ST ALBANS        230000
# KT22                       MOLE VALLEY        246500
# KT8                          ELMBRIDGE        351000
# KT17                   EPSOM AND EWELL        270000
# RM6                          REDBRIDGE        240000
# IG3                          REDBRIDGE        345000
# IG1                          REDBRIDGE        258000
# HX7                         CALDERDALE        145000
# HX6                         CALDERDALE         85000
# KT1               KINGSTON UPON THAMES        405000
# HX1                         CALDERDALE         88500
# HP4                            DACORUM        275000
# HP3                            DACORUM        280000
# HP23                           DACORUM        217000
# HG5                          HARROGATE        119250
# HG3                          HARROGATE        193000
# HG2                          HARROGATE        198000
# HG1                          HARROGATE        220000
# WD4                            DACORUM        248000
# KT5               KINGSTON UPON THAMES        337000
# KT6               KINGSTON UPON THAMES        396375
# KT9               KINGSTON UPON THAMES        290000
# LE11                         CHARNWOOD        129000
# LE10             HINCKLEY AND BOSWORTH        119750
# WN8                    WEST LANCASHIRE         62500
# RH5                        MOLE VALLEY        190000
# RH4                        MOLE VALLEY        238500
# KT21                       MOLE VALLEY        320000
# KT4                    EPSOM AND EWELL        355000
# KT19                   EPSOM AND EWELL        269000
# KT18                   EPSOM AND EWELL        347500
# BB1              BLACKBURN WITH DARWEN         83500
# B78                 NORTH WARWICKSHIRE        151400
# BL5                             BOLTON        107500
# B47                         BROMSGROVE        138750
# AL8                    WELWYN HATFIELD        275000
# AL6                    WELWYN HATFIELD        310000
# AL5                          ST ALBANS        317500
# B18                         BIRMINGHAM        159750
# B42                         BIRMINGHAM        103000
# B5                          BIRMINGHAM         95000
# B7                          BIRMINGHAM         79500
# B69                           SANDWELL         95500
# B66                           SANDWELL         72500
# CV10                NORTH WARWICKSHIRE        110500
# RM9               BARKING AND DAGENHAM        455000
# B46                 NORTH WARWICKSHIRE        196500
# B60                         BROMSGROVE        140000
# B45                         BROMSGROVE        125000
# BL4                             BOLTON         81500
# CV7                           SOLIHULL        123250
# B93                           SOLIHULL        255000
# B92                           SOLIHULL        151000
# B91                           SOLIHULL        205000
# B90                           SOLIHULL        150750
# B37                           SOLIHULL         98000
# B8                          BIRMINGHAM         52500
# B74                         BIRMINGHAM        179750
# B73                         BIRMINGHAM        145500
# DY4                           SANDWELL         85500
# RH15                        MID SUSSEX        210000
# RH16                        MID SUSSEX        235000
# RH17                        MID SUSSEX        175000
# AL9                    WELWYN HATFIELD        302477
# EN6                    WELWYN HATFIELD        291750
# B11                         BIRMINGHAM        193000
# B15                         BIRMINGHAM        182000
# BL3                             BOLTON         85600
# BD23                            CRAVEN        199950
# BD21                          BRADFORD         93000
# BD20                          BRADFORD        139000
# BD18                          BRADFORD        106498
# BD17                          BRADFORD         95000
# BD16                          BRADFORD        110000
# BD10                          BRADFORD        105475
# BB7                      RIBBLE VALLEY        138750
# BB5                           HYNDBURN         52000
# BB12                           BURNLEY         70748
# BB11                           BURNLEY        116250
# BB3              BLACKBURN WITH DARWEN         80250
# BB2              BLACKBURN WITH DARWEN         90000
# B77                           TAMWORTH        115250
# BL7                             BOLTON        159500
# WS10                          SANDWELL        103500
# B70                           SANDWELL         90000
# B33                         BIRMINGHAM        104500
# B31                         BIRMINGHAM        131000
# B30                         BIRMINGHAM        135000
# B29                         BIRMINGHAM        110000
# B28                         BIRMINGHAM        127500
# B27                         BIRMINGHAM        103000
# B23                         BIRMINGHAM         84975
# B38                         BIRMINGHAM         85000
# B20                         BIRMINGHAM         87875
# IG11              BARKING AND DAGENHAM        200000
# WA16                     CHESHIRE EAST        135000
# LE7                          CHARNWOOD        134500
# ST14                EAST STAFFORDSHIRE        125750
# HA0                              BRENT        269000
# SL5                   BRACKNELL FOREST        360000
# RG12                  BRACKNELL FOREST        215000
# RH14                        CHICHESTER        218000
# TW20                         RUNNYMEDE        275000
# CR5               REIGATE AND BANSTEAD        272994
# KT16                         RUNNYMEDE        249950
# E15                             NEWHAM        360000
# HD8                           KIRKLEES        170250
# E12                             NEWHAM        235000
# E17                     WALTHAM FOREST        416000
# DE7                            EREWASH         85000
# DE21                           EREWASH         82500
# DE14                EAST STAFFORDSHIRE        129500
# LE13                            MELTON        137000
# DE23                             DERBY         90000
# DE1                              DERBY        111250
# DA11                         GRAVESHAM        183000
# DE4                   DERBYSHIRE DALES        295000
# DA9                           DARTFORD        235000
# DA8                             BEXLEY        228750
# DA7                             BEXLEY        269975
# DA5                             BEXLEY        270000
# DA17                            BEXLEY        226250
# DA16                            BEXLEY        201250
# DA15                            BEXLEY        284000
# DA1                             BEXLEY        227500
# DA10                          DARTFORD        261000
# HA3                              BRENT        261500
# HA9                              BRENT        312500
# HA1                             HARROW        320000
# HA2                             HARROW        320000
# EN8                         BROXBOURNE        206250
# EN11                        BROXBOURNE        240000
# EN10                        BROXBOURNE        235000
# EN4                            ENFIELD        286000
# EN3                            ENFIELD        255000
# EN2                            ENFIELD        285000
# EN1                            ENFIELD        265000
# EN5                             BARNET        330000
# EC2Y                    CITY OF LONDON        670000
# EC1M                         ISLINGTON        716000
# E9                             HACKNEY        450000
# E8                             HACKNEY        575000
# E5                             HACKNEY        341243
# E2                             HACKNEY        550000
# E7                              NEWHAM        340000
# E20                             NEWHAM        577500
# EC1V                         ISLINGTON        830000
# RG27                              HART        262000
# KT14                            WOKING        290000
# KT15                         RUNNYMEDE        252000
# HD7                           KIRKLEES        109000
# HD1                           KIRKLEES        102500
# UB9                         HILLINGDON        322500
# UB7                         HILLINGDON        263750
# UB3                         HILLINGDON        310000
# HA5                         HILLINGDON        384000
# HA4                         HILLINGDON        363500
# S32                   DERBYSHIRE DALES        485000
# SK17                  DERBYSHIRE DALES        184950
# DE55                          BOLSOVER         64000
# LU7               CENTRAL BEDFORDSHIRE        190000
# LU1                              LUTON        153500
# WF3                              LEEDS        115000
# LE2                  OADBY AND WIGSTON        146000
# LE18                 OADBY AND WIGSTON        123000
# SG15              CENTRAL BEDFORDSHIRE        148000
# OL11                          ROCHDALE         69750
# OL15                          ROCHDALE        129000
# M27                            SALFORD        125000
# MK9                      MILTON KEYNES        290000
# MK3                      MILTON KEYNES        196250
# MK2                      MILTON KEYNES        115000
# MK17                     MILTON KEYNES        150000
# MK12                     MILTON KEYNES        161000
# SK14                          TAMESIDE        110000
# OL6                           TAMESIDE        226750
# OL5                           TAMESIDE        132000
# M34                           TAMESIDE        107500
# WA15                          TRAFFORD        162975
# WA14                          TRAFFORD        236750
# M41                           TRAFFORD        212250
# M32                           TRAFFORD        125000
# M5                             SALFORD        145500
# M30                            SALFORD        127500
# M3                             SALFORD        220000
# M28                            SALFORD        172500
# LE15                           RUTLAND        141000
# WF13                          KIRKLEES         59500
# LU5               CENTRAL BEDFORDSHIRE        177000
# MK45              CENTRAL BEDFORDSHIRE        225000
# E11                     WALTHAM FOREST        402500
# SG18              CENTRAL BEDFORDSHIRE        195000
# E10                     WALTHAM FOREST        370000
# E1W                      TOWER HAMLETS        686000
# E14                      TOWER HAMLETS        442500
# E1                       TOWER HAMLETS        475000
# WV14                            DUDLEY         70000
# DY9                             DUDLEY        174250
# DY8                             DUDLEY        140000
# DY10                       WYRE FOREST        106500
# DL7                          HAMBLETON        124950
# DL3                         DARLINGTON        108000
# DL1                         DARLINGTON         70000
# DL14                     COUNTY DURHAM         54125
# DH2                      COUNTY DURHAM         78000
# DH1                      COUNTY DURHAM         98500
# DE65                  SOUTH DERBYSHIRE        122500
# DE56                      AMBER VALLEY        184000
# E4                      WALTHAM FOREST        296000
# HD9                           KIRKLEES        186000
# WF14                          KIRKLEES         76000
# M40                         MANCHESTER         63500
# M20                         MANCHESTER        225000
# M19                         MANCHESTER        113500
# M14                         MANCHESTER        129750
# M11                         MANCHESTER        127500
# M1                          MANCHESTER        221250
# SG19              CENTRAL BEDFORDSHIRE        158000
# M24                           ROCHDALE         91000
# KT20              REIGATE AND BANSTEAD        279000
# SY1                         SHROPSHIRE        113750
# SM4                             MERTON        317500
# S60                          ROTHERHAM        105000
# RM13                          HAVERING        233000
# TW17                        SPELTHORNE        304975
# TW18                        SPELTHORNE        258000
# TW19            WINDSOR AND MAIDENHEAD        275000
# UB6                             EALING        272800
# RG17                    WEST BERKSHIRE        176500
# RG19                    WEST BERKSHIRE        200000
# RG30                    WEST BERKSHIRE        209000
# SK23                         HIGH PEAK        110000
# SK22                         HIGH PEAK        160000
# RG31                    WEST BERKSHIRE        166250
# SK13                         HIGH PEAK        115000
# S33                          HIGH PEAK        245000
# WA2                         WARRINGTON        106000
# WF7                          WAKEFIELD         71000
# N1C                             CAMDEN       1050000
# S41                       CHESTERFIELD        112000
# WA1                         WARRINGTON         98750
# S26                          ROTHERHAM        100000
# S9                           SHEFFIELD         71500
# W5                              EALING        445000
# S36                          SHEFFIELD        112500
# W3                              EALING        350000
# S35                          SHEFFIELD        110000
# S17                          SHEFFIELD        154300
# S13                          SHEFFIELD        125000
# S1                           SHEFFIELD        116250
# RM19                          THURROCK        200000
# RH20                           HORSHAM        247475
# RH13                           HORSHAM        241000
# RM14                          HAVERING        276000
# RM2                           HAVERING        225000
# SE3                          GREENWICH        416000
# WF1                          WAKEFIELD        112500
# WD7                          HERTSMERE        347475
# SE2                          GREENWICH        247500
# SE18                         GREENWICH        290000
# SE13                          LEWISHAM        347500
# SK4                          STOCKPORT        118000
# S71                           BARNSLEY        134250
# RG14                    WEST BERKSHIRE        205000
# TW16                        SPELTHORNE        270000
# TW15                        SPELTHORNE        267000
# UB2                           HOUNSLOW        295000
# RG7                     WEST BERKSHIRE        246000
# RG21             BASINGSTOKE AND DEANE        175000
# RG26             BASINGSTOKE AND DEANE        165000
# RG41                         WOKINGHAM        237500
# RM18                          THURROCK        195000
# RM17                          THURROCK        190000
# RM16                          THURROCK        215000
# RM15                          THURROCK        190000
# RG45                         WOKINGHAM        247000
# RG6                          WOKINGHAM        200500
# RH10                           CRAWLEY        224250
# RH11                           CRAWLEY        179500
# RH12                           HORSHAM        220000
# RM3                           HAVERING        265000
# TW8                           HOUNSLOW        422500
# W13                             EALING        387000
# W7                              EALING        395000
# SK5                          STOCKPORT        120550
# TW9               RICHMOND UPON THAMES        593500
# TW12              RICHMOND UPON THAMES        364000
# TW11              RICHMOND UPON THAMES        375000
# TW1               RICHMOND UPON THAMES        412500
# SY11                        SHROPSHIRE         97500
# SY6                         SHROPSHIRE        100000
# SY7                         SHROPSHIRE        133500
# WS12                     CANNOCK CHASE        112500
# WS11                     CANNOCK CHASE        120000
# RG9                  SOUTH OXFORDSHIRE        470000
# RM11                          HAVERING        258000
# SM6                             SUTTON        270000
# TW13                          HOUNSLOW        235000
# WR9                           WYCHAVON        166000
# SM1                             SUTTON        282000
# SM2                             SUTTON        271500
# TW3                           HOUNSLOW        250000
# SM5                             SUTTON        278500
# TW7                           HOUNSLOW        348120
# SL3                             SLOUGH        231333
# WR10                          WYCHAVON         87500
# SL2                             SLOUGH        200000
# WR4                          WORCESTER        100500
# WR11                          WYCHAVON        125000
# SL1                             SLOUGH        201000
# SK8                          STOCKPORT        205500
# SK7                          STOCKPORT        125000
# SN1                            SWINDON        131000
# TW2               RICHMOND UPON THAMES        399000
# W12             HAMMERSMITH AND FULHAM        545000
# SE7                          GREENWICH        355000
# W14             HAMMERSMITH AND FULHAM        547500
# SK6                          STOCKPORT        127500
# TF2                 TELFORD AND WREKIN         95250
# TF3                 TELFORD AND WREKIN         95500
# ST6                     STOKE-ON-TRENT         65500
# ST4                     STOKE-ON-TRENT         81000
# WS3                            WALSALL        110000
# ST3                     STOKE-ON-TRENT         71250
# WS2                            WALSALL         85000
# ST16                          STAFFORD        130000
# ST15                          STAFFORD        131000
# WS1                            WALSALL         81250
# WR1                          WORCESTER        135000
# WR14                     MALVERN HILLS        202750
# SW1V                       WESTMINSTER        835000
# W2                         WESTMINSTER        811000
# SP10                       TEST VALLEY        140500
# WR13                     MALVERN HILLS        222000
# OL3                             OLDHAM        193000
# TF1                 TELFORD AND WREKIN         84500
# RG8                  SOUTH OXFORDSHIRE        315000
# TF11                        SHROPSHIRE        175000
# SY8                         SHROPSHIRE        102475
# WV8                SOUTH STAFFORDSHIRE        182257
# WV1                      WOLVERHAMPTON        106250
# WS14                         LICHFIELD        149500
# WS13                         LICHFIELD        144000
# WS15                     CANNOCK CHASE         95000
# WF10                         WAKEFIELD         80000
# WF8                          WAKEFIELD         89000
# KT3                             MERTON        313850
# SE9                            BROMLEY        282500
# CV5                           COVENTRY        146000
# CV4                           COVENTRY        128750
# CM77                         BRAINTREE        192500
# CM7                          BRAINTREE        152000
# SG14                EAST HERTFORDSHIRE        270000
# SG13                EAST HERTFORDSHIRE        299500
# CB11                        UTTLESFORD        180000
# CB10                        UTTLESFORD        220500
# CB4                          CAMBRIDGE        237500
# CB1                          CAMBRIDGE        295000
# DA4                          SEVENOAKS        228000
# DA3                          SEVENOAKS        237500
# BR8                          SEVENOAKS        250000
# SE20                           BROMLEY        277500
# WF9                          WAKEFIELD         82500
# BR7                            BROMLEY        252500
# BR6                            BROMLEY        320000
# BR5                            BROMLEY        237500
# BR4                            BROMLEY        190000
# BR3                            BROMLEY        317500
# BR2                            BROMLEY        300000
# BR1                            BROMLEY        328000
# RH19                        MID SUSSEX        217000
# CB22              SOUTH CAMBRIDGESHIRE        280500
# MK40                           BEDFORD        167250
# SG8               SOUTH CAMBRIDGESHIRE        212500
# CB7                EAST CAMBRIDGESHIRE        157500
# SG12                EAST HERTFORDSHIRE        230000
# CV6                           COVENTRY        122000
# CV11             NUNEATON AND BEDWORTH        106250
# CV12             NUNEATON AND BEDWORTH        100000
# CV21                             RUGBY        123000
# CR4                             MERTON        265000
# RH9                          TANDRIDGE        332500
# RH8                          TANDRIDGE        425250
# RH2               REIGATE AND BANSTEAD        318500
# RH1                          TANDRIDGE        235000
# SE25                           CROYDON        282000
# SE19                           CROYDON        368000
# CR8                            CROYDON        280000
# CR7                            CROYDON        260000
# CR2                            CROYDON        279000
# CR0                            CROYDON        250000
# CM8                          BRAINTREE        193500
# CR3                          TANDRIDGE        265000
# RH6               REIGATE AND BANSTEAD        222500
# SM7               REIGATE AND BANSTEAD        307500
# CV1                           COVENTRY        118750
# SK12                     CHESHIRE EAST        146500
# SK11                     CHESHIRE EAST        112500
# SK10                     CHESHIRE EAST        125000
# CW5                      CHESHIRE EAST        153000
# CW4                      CHESHIRE EAST         97500
# CW2                      CHESHIRE EAST         63500
# ...
# HG5                     0.000000
# HG3                     0.000000
# HG2                     0.000000
# HG1                     0.000000
# WD4                     0.000000
# KT5                     0.000000
# KT6                     0.000000
# KT9                     0.000000
# LE11                    0.000000
# LE10                    0.000000
# WN8                     0.000000
# RH5                     0.000000
# RH4                     0.000000
# KT21                    0.000000
# KT4                     0.000000
# KT19                    0.000000
# KT18                    0.000000
# BB1                     0.000000
# B78                     0.000000
# BL5                     0.000000
# B47                     0.000000
# AL8                     0.000000
# AL6                     0.000000
# AL5                     0.000000
# B18                     0.000000
# B42                     0.000000
# B5                      0.000000
# B7                      0.000000
# B69                     0.000000
# B66                     0.000000
# CV10                    0.000000
# RM9                     0.000000
# B46                     0.000000
# B60                     0.000000
# B45                     0.000000
# BL4                     0.000000
# CV7                     0.000000
# B93                     0.000000
# B92                     0.000000
# B91                     0.000000
# B90                     0.000000
# B37                     0.000000
# B8                      0.000000
# B74                     0.000000
# B73                     0.000000
# DY4                     0.000000
# RH15                    0.000000
# RH16                    0.000000
# RH17                    0.000000
# AL9                     0.000000
# EN6                     0.000000
# B11                     0.000000
# B15                     0.000000
# BL3                     0.000000
# BD23                    0.000000
# BD21                    0.000000
# BD20                    0.000000
# BD18                    0.000000
# BD17                    0.000000
# BD16                    0.000000
# BD10                    0.000000
# BB7                     0.000000
# BB5                     0.000000
# BB12                    0.000000
# BB11                    0.000000
# BB3                     0.000000
# BB2                     0.000000
# B77                     0.000000
# BL7                     0.000000
# WS10                    0.000000
# B70                     0.000000
# B33                     0.000000
# B31                     0.000000
# B30                     0.000000
# B29                     0.000000
# B28                     0.000000
# B27                     0.000000
# B23                     0.000000
# B38                     0.000000
# B20                     0.000000
# IG11                    0.000000
# WA16                    0.000000
# LE7                     0.000000
# ST14                    0.000000
# HA0                     0.000000
# SL5                     0.000000
# RG12                    0.000000
# RH14                    0.000000
# TW20                    0.000000
# CR5                     0.000000
# KT16                    0.000000
# E15                     0.000000
# HD8                     0.000000
# E12                     0.000000
# E17                     0.000000
# DE7                     0.000000
# DE21                    0.000000
# DE14                    0.000000
# LE13                    0.000000
# DE23                    0.000000
# DE1                     0.000000
# DA11                    0.000000
# DE4                     0.000000
# DA9                     0.000000
# DA8                     0.000000
# DA7                     0.000000
# DA5                     0.000000
# DA17                    0.000000
# DA16                    0.000000
# DA15                    0.000000
# DA1                     0.000000
# DA10                    0.000000
# HA3                     0.000000
# HA9                     0.000000
# HA1                     0.000000
# HA2                     0.000000
# EN8                     0.000000
# EN11                    0.000000
# EN10                    0.000000
# EN4                     0.000000
# EN3                     0.000000
# EN2                     0.000000
# EN1                     0.000000
# EN5                     0.000000
# EC2Y                    0.000000
# EC1M                    0.000000
# E9                      0.000000
# E8                      0.000000
# E5                      0.000000
# E2                      0.000000
# E7                      0.000000
# E20                     0.000000
# EC1V                    0.000000
# RG27                    0.000000
# KT14                    0.000000
# KT15                    0.000000
# HD7                     0.000000
# HD1                     0.000000
# UB9                     0.000000
# UB7                     0.000000
# UB3                     0.000000
# HA5                     0.000000
# HA4                     0.000000
# S32                     0.000000
# SK17                    0.000000
# DE55                    0.000000
# LU7                     0.000000
# LU1                     0.000000
# WF3                     0.000000
# LE2                     0.000000
# LE18                    0.000000
# SG15                    0.000000
# OL11                    0.000000
# OL15                    0.000000
# M27                     0.000000
# MK9                     0.000000
# MK3                     0.000000
# MK2                     0.000000
# MK17                    0.000000
# MK12                    0.000000
# SK14                    0.000000
# OL6                     0.000000
# OL5                     0.000000
# M34                     0.000000
# WA15                    0.000000
# WA14                    0.000000
# M41                     0.000000
# M32                     0.000000
# M5                      0.000000
# M30                     0.000000
# M3                      0.000000
# M28                     0.000000
# LE15                    0.000000
# WF13                    0.000000
# LU5                     0.000000
# MK45                    0.000000
# E11                     0.000000
# SG18                    0.000000
# E10                     0.000000
# E1W                     0.000000
# E14                     0.000000
# E1                      0.000000
# WV14                    0.000000
# DY9                     0.000000
# DY8                     0.000000
# DY10                    0.000000
# DL7                     0.000000
# DL3                     0.000000
# DL1                     0.000000
# DL14                    0.000000
# DH2                     0.000000
# DH1                     0.000000
# DE65                    0.000000
# DE56                    0.000000
# E4                      0.000000
# HD9                     0.000000
# WF14                    0.000000
# M40                     0.000000
# M20                     0.000000
# M19                     0.000000
# M14                     0.000000
# M11                     0.000000
# M1                      0.000000
# SG19                    0.000000
# M24                     0.000000
# KT20                    0.000000
# SY1                     0.000000
# SM4                     0.000000
# S60                     0.000000
# RM13                    0.000000
# TW17                    0.000000
# TW18                    0.000000
# TW19                    0.000000
# UB6                     0.000000
# RG17                    0.000000
# RG19                    0.000000
# RG30                    0.000000
# SK23                    0.000000
# SK22                    0.000000
# RG31                    0.000000
# SK13                    0.000000
# S33                     0.000000
# WA2                     0.000000
# WF7                     0.000000
# N1C                     0.000000
# S41                     0.000000
# WA1                     0.000000
# S26                     0.000000
# S9                      0.000000
# W5                      0.000000
# S36                     0.000000
# W3                      0.000000
# S35                     0.000000
# S17                     0.000000
# S13                     0.000000
# S1                      0.000000
# RM19                    0.000000
# RH20                    0.000000
# RH13                    0.000000
# RM14                    0.000000
# RM2                     0.000000
# SE3                     0.000000
# WF1                     0.000000
# WD7                     0.000000
# SE2                     0.000000
# SE18                    0.000000
# SE13                    0.000000
# SK4                     0.000000
# S71                     0.000000
# RG14                    0.000000
# TW16                    0.000000
# TW15                    0.000000
# UB2                     0.000000
# RG7                     0.000000
# RG21                    0.000000
# RG26                    0.000000
# RG41                    0.000000
# RM18                    0.000000
# RM17                    0.000000
# RM16                    0.000000
# RM15                    0.000000
# RG45                    0.000000
# RG6                     0.000000
# RH10                    0.000000
# RH11                    0.000000
# RH12                    0.000000
# RM3                     0.000000
# TW8                     0.000000
# W13                     0.000000
# W7                      0.000000
# SK5                     0.000000
# TW9                     0.000000
# TW12                    0.000000
# TW11                    0.000000
# TW1                     0.000000
# SY11                    0.000000
# SY6                     0.000000
# SY7                     0.000000
# WS12                    0.000000
# WS11                    0.000000
# RG9                     0.000000
# RM11                    0.000000
# SM6                     0.000000
# TW13                    0.000000
# WR9                     0.000000
# SM1                     0.000000
# SM2                     0.000000
# TW3                     0.000000
# SM5                     0.000000
# TW7                     0.000000
# SL3                     0.000000
# WR10                    0.000000
# SL2                     0.000000
# WR4                     0.000000
# WR11                    0.000000
# SL1                     0.000000
# SK8                     0.000000
# SK7                     0.000000
# SN1                     0.000000
# TW2                     0.000000
# W12                     0.000000
# SE7                     0.000000
# W14                     0.000000
# SK6                     0.000000
# TF2                     0.000000
# TF3                     0.000000
# ST6                     0.000000
# ST4                     0.000000
# WS3                     0.000000
# ST3                     0.000000
# WS2                     0.000000
# ST16                    0.000000
# ST15                    0.000000
# WS1                     0.000000
# WR1                     0.000000
# WR14                    0.000000
# SW1V                    0.000000
# W2                      0.000000
# SP10                    0.000000
# WR13                    0.000000
# OL3                     0.000000
# TF1                     0.000000
# RG8                     0.000000
# TF11                    0.000000
# SY8                     0.000000
# WV8                     0.000000
# WV1                     0.000000
# WS14                    0.000000
# WS13                    0.000000
# WS15                    0.000000
# WF10                    0.000000
# WF8                     0.000000
# KT3                     0.000000
# SE9                     0.000000
# CV5                     0.000000
# CV4                     0.000000
# CM77                    0.000000
# CM7                     0.000000
# SG14                    0.000000
# SG13                    0.000000
# CB11                    0.000000
# CB10                    0.000000
# CB4                     0.000000
# CB1                     0.000000
# DA4                     0.000000
# DA3                     0.000000
# BR8                     0.000000
# SE20                    0.000000
# WF9                     0.000000
# BR7                     0.000000
# BR6                     0.000000
# BR5                     0.000000
# BR4                     0.000000
# BR3                     0.000000
# BR2                     0.000000
# BR1                     0.000000
# RH19                    0.000000
# CB22                    0.000000
# MK40                    0.000000
# SG8                     0.000000
# CB7                     0.000000
# SG12                    0.000000
# CV6                     0.000000
# CV11                    0.000000
# CV12                    0.000000
# CV21                    0.000000
# CR4                     0.000000
# RH9                     0.000000
# RH8                     0.000000
# RH2                     0.000000
# RH1                     0.000000
# SE25                    0.000000
# SE19                    0.000000
# CR8                     0.000000
# CR7                     0.000000
# CR2                     0.000000
# CR0                     0.000000
# CM8                     0.000000
# CR3                     0.000000
# RH6                     0.000000
# SM7                     0.000000
# CV1                     0.000000
# SK12                    0.000000
# SK11                    0.000000
# SK10                    0.000000
# CW5                     0.000000
# CW4                     0.000000
# CW2                     0.000000
# CW12                    0.000000
# CW11                    0.000000
# CV34                    0.000000
# CV31                    0.000000
# CV8                     0.000000
# CM23                    0.000000
# CM21                    0.000000
# CM20                    0.000000
# WN1                     0.000000
# SE16                    0.000000
# SE1                     0.000000
# WA9                     0.000000
# WA12                    0.000000
# S75                     0.000000
# WA11                    0.000000
# WA5                     0.000000
# S73                     0.000000
# WD6                     0.000000
# SE26                    0.000000
# SE5                     0.000000
# SE10                    0.000000
# SK2                     0.000000
# SK1                     0.000000
# SG6                     0.000000
# SG4                     0.000000
# SG3                     0.000000
# SG1                     0.000000
# SE27                    0.000000
# SE8                     0.000000
# SE6                     0.000000
# SE4                     0.000000
# SE15                    0.000000
# RG1                     0.000000
# SE14                    0.000000
# SE12                    0.000000
# RM1                     0.000000
# WA3                     0.000000
# WN5                     0.000000
# CM19                    0.000000
# SE17                    0.000000
# CM15                    0.000000
# CM14                    0.000000
# CM13                    0.000000
# CM12                    0.000000
# CM3                     0.000000
# CM1                     0.000000
# CM0                     0.000000
# WA6                     0.000000
# CW9                     0.000000
# CW8                     0.000000
# CW7                     0.000000
# CB8                     0.000000
# CB6                     0.000000
# MK42                    0.000000
# AL1                     0.000000
# W4                      0.000000
# SE24                    0.000000
# SE23                    0.000000
# SE22                    0.000000
# WD3                     0.000000
# WD25                    0.000000
# WD24                    0.000000
# WD19                    0.000000
# SE21                    0.000000
# WD17                    0.000000
# WA8                     0.000000
# WA7                     0.000000
# KT13                    0.000000
#
# [923 rows x 33 columns]

# %%
os.getcwd()

# %% [markdown]
# # Flat calculations

# %%
columns=["Transaction unique identifier","Price","Date of Transfer","Postcode","Property Type","Old/New","Duration","PAON","SAON","Street","Locality","Town/City","District","County","PPD Category Type","TBD"]
postcodes_with_train_times_df=pd.read_excel("C:\\Users\\Carl\\Housing\\postcodedfwithtimedf.xlsx")
pp2022=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2022.csv")
pp2022.columns=columns
postcodemappings=pd.read_csv(open("C:\\Users\\Carl\\Housing\\Data\\Postcode to LA.csv"),sep='\t',error_bad_lines=False)

deprivation_scores=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\Deprivation Scores.xlsx','rb'),"IMD2019")

retail_info=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\RetailInfo.xlsx','rb'),"Table 1",usecols=[1,7],skiprows=range(5))
retail_info=retail_info.dropna()
retail_info=retail_info.rename(columns={"Unnamed: 1":"Local Authority","47 : Retail":"Count"})
retail_info.set_index("Local Authority",inplace=True)
retail_infodict=retail_info.to_dict(orient="index")

crimedf=pd.read_excel(open("C:\\Users\\Carl\\Housing\\Data\\Crime Data.xlsx","rb"),"Table C3",skiprows=range(6))
crimedf.columns=[string.replace("\n","") for string in list(crimedf.columns)]
crimedf=crimedf[["Local Authority name","Total recorded crime (excluding fraud)"]]
crimedf.dropna(subset=["Local Authority name"],inplace=True)
crimedf=crimedf.set_index("Local Authority name")
crimedfdict=crimedf.to_dict(orient="index")

population_info=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\PopulationFigures.xlsx','rb'),"Ethnicity",usecols=[3,4],skiprows=range(6))
population_info=population_info.dropna()
population_info=population_info.rename(columns={" .1":"Local Authority","Number":"Population"})
population_info.set_index("Local Authority",inplace=True)
population_infodict=population_info.to_dict(orient="index")

areasizeinfo=pd.read_excel(open('C:\\Users\\Carl\\Housing\\Data\\SAM_LAD_DEC_2020_UK.xlsx','rb'),"SAM_LAD_2020",usecols=[1,2])
areasizeinfo=areasizeinfo.dropna()
areasizeinfo.rename(columns={"LAD20NM":"Local Authority","AREAEHECT":"Area (Hectares)"},inplace=True)
areasizeinfo.set_index("Local Authority",inplace=True)
areasizeinfodict=areasizeinfo.to_dict(orient="index")
areasizeinfodict["Hartlepool"]

dct={}
for year in range(2008,2021):
    df=pd.read_csv(str(os.getcwd())+"\\Data\\square footage\\KT1_"+str(year)+"_flat_data.csv",usecols=[1,2,3,4,31])
    dct[year]=df
flatsizesinkingston=pd.concat(dct.values())
flatsizesinkingston=flatsizesinkingston.reset_index()
flatsizesinkingston=flatsizesinkingston.drop(columns=["index"])
medianflatsizeinkingstonla=flatsizesinkingston[["total-floor-area"]].median().values[0]
print("medianflatsizeinkingstonla=",medianflatsizeinkingstonla)

# %%
pd.set_option('display.max_rows', None)
#pp2020=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2020.csv")
#pp2020.columns=columns
#pp2021=pd.read_csv("C:\\Users\\Carl\\Housing\\Data\\pp-2021.csv")
#pp2021.columns=columns

print("shape of input df is",pp2022.shape)

pp2022['Property Type']=pp2022["Property Type"].str.replace("D","Detached")
pp2022['Property Type']=pp2022["Property Type"].str.replace("S","Semi-Detached")
pp2022['Property Type']=pp2022["Property Type"].str.replace("T","Terraced")
pp2022['Property Type']=pp2022["Property Type"].str.replace("F","Flat")
pp2022["Property Type"]=pp2022["Property Type"].str.replace("O","Other")

print("\nthis is the breakdown by house type across all areas\n",pp2022["Property Type"].value_counts())

fpp2022=pp2022[pp2022["Property Type"]=="Flat"]
print("\n flats sold since 2022\n",fpp2022.shape)

fpp2022.reset_index(inplace=True,drop=True)

fpp2022.dropna(subset=["Postcode"],inplace=True)
fpp2022.reset_index(inplace=True,drop=True)

fpp2022dict=fpp2022.to_dict(orient="index")
print(fpp2022dict[2])

for i in range(0,len(fpp2022)):
    try:
        postcode=list(fpp2022dict.get(i).items())[3][1]
        first_postcode=postcode.split(" ")[0]
        fpp2022dict[i]["First Postcode"]=first_postcode
    except:
        print(postcode)
print("\nFlat price dictionary since 2022 has",len(fpp2022dict.keys()),"keys\n")

fpp2022dictdf=pd.DataFrame.from_dict(fpp2022dict,orient="index")
print("\nFlat price dictionary df (with split postcode) since 2022 has",fpp2022dictdf.shape[0],"rows")


fpp2022dictdf['Month of Transfer'] = pd.DatetimeIndex(fpp2022dictdf['Date of Transfer']).month
fpp2022dictdf['Month of Transfer']=fpp2022dictdf['Month of Transfer'].replace(1,"January")
fpp2022dictdf['Month of Transfer']=fpp2022dictdf['Month of Transfer'].replace(2,"Febuary")
fpp2022dictdf['Month of Transfer']=fpp2022dictdf['Month of Transfer'].replace(3,"March")
fpp2022dictdf['Month of Transfer']=fpp2022dictdf['Month of Transfer'].replace(4,"April")
fpp2022dictdf['Month of Transfer']=fpp2022dictdf['Month of Transfer'].replace(5,"May")

unique_sold_first_postcodes=list(fpp2022dictdf["First Postcode"].unique())

print("\nthere are",len(unique_sold_first_postcodes),"postcodes that had a flat sale in 2022\n")

singlesalepostcodes=fpp2022dictdf[fpp2022dictdf.groupby('First Postcode')['Price'].transform('size') == 1]
print("\nthere were",len(singlesalepostcodes["First Postcode"].unique()),"postcodes with a single sale in 2022\n")

fpp2022dictdf=fpp2022dictdf[fpp2022dictdf.groupby('First Postcode')['Price'].transform('size') > 1]
print("\nthere were",len(fpp2022dictdf["First Postcode"].unique()),"postcodes more than a single sale in 2022\n")

fpp2022dictdf["Price"]=fpp2022dictdf["Price"].astype(str)
fpp2022dictdfgrouped=fpp2022dictdf.groupby(['First Postcode'])['Price'].apply(','.join).reset_index()
fpp2022dictdfgrouped
fpp2022dictdfgrouped.rename(columns={"Price":"All Prices for First Postcode"},inplace=True)
fpp2022dictdfgrouped.drop_duplicates(subset=["First Postcode"],inplace=True)
fpp2022dictdfgrouped.reset_index(inplace=True,drop=True)
print("flat prices grouped by postcode has",fpp2022dictdfgrouped.shape[0],"rows")

fpp2022dictdfgrouped[fpp2022dictdfgrouped["First Postcode"]=="KT1"]["All Prices for First Postcode"].values

postcodes_with_train_times_df.drop(columns=["Unnamed: 0"],inplace=True)
print("splitting postcodes in train time df...")
postcodes_with_train_times_df["First Postcode"]="tbd"
for i in range(0,len(postcodes_with_train_times_df)):
    postcode=postcodes_with_train_times_df.loc[i]["postcode"]
    split_postcode=postcode.split(" ")
    postcodes_with_train_times_df.loc[postcodes_with_train_times_df['postcode'] == postcode, 'First Postcode'] = split_postcode[0]
postcodes_with_train_times_df.head()
#postcodes_with_train_times_df=postcodes_with_train_times_df[postcodes_with_train_times_df["train time to work"]<75]
print("train times all gathered...")
print("merging train time df with house prices grouped by first postcode...")
finaldf=pd.merge(fpp2022dictdfgrouped,postcodes_with_train_times_df[["First Postcode","train time to work"]],on="First Postcode")
print("Done")
finaldf["train time to work"]=finaldf["train time to work"].astype(str)
print("Joining finaldf train times into a single comma seperated string...")
commutedf=finaldf.groupby("First Postcode")['train time to work'].apply(','.join).reset_index()
#commutedf.set_index("First Postcode",inplace=True)
print("Done")
print("merging finaldf with commuter df ...")
commutedf=pd.merge(finaldf,commutedf,on="First Postcode")
print("Done")
commutedf.drop(columns="train time to work_x",inplace=True)
commutedf.rename(columns={"train time to work_y":"train time to work"},inplace=True)
commutedf.drop_duplicates("First Postcode",inplace=True)
commutedf.head()
commutedf.set_index("First Postcode",inplace=True)
print("putting commutedf into a dictionary...")
commutedict=commutedf.to_dict(orient="index")
print("Done")
#print(commutedict)
#hpp2022dictdfgrouped.head()

# %%
print("calculating the median prices and median times for each postcode")
for postcode,data in commutedict.items():
    data=commutedict.get(postcode)
    prices=data.get("All Prices for First Postcode").split(",")
    prices=[float(price) for price in prices]
    times=data.get("train time to work").split(",")
    times=[float(time) for time in times]
    mediantime=round(statistics.median(times))
    medianprice=round(statistics.median(prices))
    if postcode=="KT1":
        print(medianprice,postcode,"this is the median price for KT1")
    commutedict[postcode]['Median Price']=medianprice
    commutedict[postcode]['Median Time']=mediantime
print("Done")
print("putting the last df into a df to adjust index and drop columns")
lastdf=pd.DataFrame.from_dict(commutedict,orient="index")
lastdf.reset_index(inplace=True)
lastdf=lastdf[["index","Median Price","Median Time"]]
lastdf.set_index("index",inplace=True)
print("Done")
print("putting the last df back into a dict as the last step")
lastdfdict=lastdf.to_dict(orient="index")
print("Lastdf written to dict")
lastdfdict.get("E10")

postcodemappings.reset_index(inplace=True)
postcodemappings.set_index("index",inplace=True)
print("postcode df being written to df")
dict0=postcodemappings.to_dict(orient="index")
postcodeladict={}
print("postcode df dict being split to get first postcode")
for i in range(1,len(dict0.keys())):
    vals=list(dict0.get(i).values())
    for string in vals:
        PC=string.split(",")[1]
        LAV=string.split(",")[6]
        FPC=PC.split(" ")[0]
    postcodeladict[FPC]=LAV
postcodeladict.get("E10")
print("getting local authority for first postcode")
for postcode in list(lastdfdict.keys()):
    try:
        localauthority=postcodeladict[postcode]
        lastdfdict[postcode]["local authority"]=localauthority
    except:
        lastdfdict[postcode]["local authority"]="LA not known"
lastdfdict["E10"]

for postcode in list(lastdfdict.keys()):
    if "Kingston upon Thames" in lastdfdict[postcode]["local authority"]:
        lastdfdict[postcode]['Median Price over Median Area (Kingston Only)']=405000/medianflatsizeinkingstonla
        print(405000/medianflatsizeinkingstonla)
    else:
        lastdfdict[postcode]['Median Price over Median Area (Kingston Only)']=0


print("getting population for local authority")

for postcode in list(lastdfdict.keys()):
    try:
        localauthority=lastdfdict.get(postcode)["local authority"]
        population=list(population_infodict[localauthority].values())[0]
        lastdfdict[postcode]["Population"]=population
    except:
        lastdfdict[postcode]["Population"]="Population not known"
lastdfdict["E10"]


print("getting deprivation rank for local authority")

deprivation_scores_grouped=deprivation_scores.groupby('Local Authority District name (2019)')[["Index of Multiple Deprivation (IMD) Rank"]].median()
deprivation_scores_grouped.loc["Adur"][0]
alldepscores=[]
for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        deprivationscore=deprivation_scores_grouped.loc[localauthority][0]
        alldepscores.append(deprivationscore)
        lastdfdict[postcode]["Deprivation Rank"]=deprivationscore
    except:
        lastdfdict[postcode]["Deprivation Rank"]="Deprivation Unknown"
lastdfdict["E10"]


print("getting median price for area relative to median price within 2 hrs of work")

allprices=[]
for postcode in list(lastdfdict.keys()):
    allprices.append(lastdfdict[postcode]["Median Price"])
allmedianprice=statistics.median(allprices)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Postcode Median Price Relative to 2hr Radius Median Price"]=lastdfdict[postcode]["Median Price"]/allmedianprice
lastdfdict["E10"]


alltimes=[]
for postcode in list(lastdfdict.keys()):
    alltimes.append(lastdfdict[postcode]["Median Time"])
allmediantime=statistics.median(alltimes)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Postcode Median Time Relative to 2hr Radius Median Time"]=lastdfdict[postcode]["Median Time"]/allmediantime
lastdfdict["E10"]


print("getting retail counts for each local authority")

for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        retaildict=retail_infodict.get(localauthority)
        retailcount=list(retaildict.values())[0]
        lastdfdict[postcode]["Retail Count"]=retailcount
    except:
        lastdfdict[postcode]["Retail Count"]="Retail Count Unknown"
lastdfdict["E10"]


print("getting crime counts for local authority")

for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        crimecount=list(crimedfdict.get(localauthority).values())[0]
        lastdfdict[postcode]["Crime Count"]=crimecount
    except:
        lastdfdict[postcode]["Crime Count"]="Crime Count Unknown"
lastdfdict["E10"]

print("getting area for local authority")

for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    try:
        area=list(areasizeinfodict.get(localauthority).values())[0]
        lastdfdict[postcode]["Area"]=area
    except:
        lastdfdict[postcode]["Area"]="Area Unknown"
lastdfdict["E10"]





print("getting postcodes with any unknown values")


unknowndict={}
for postcode in list(lastdfdict.keys()):
    lanacount = 0
    if (lastdfdict[postcode]["local authority"]=="LA not known"):
        lanacount += 1
    popnacount = 0
    if (lastdfdict[postcode]["Population"]=="Population not known"):
        popnacount += 1
    dinacount = 0
    if (lastdfdict[postcode]["Deprivation Rank"]=="Deprivation Unknown"):
        dinacount += 1
    areanacount=0
    if (lastdfdict[postcode]["Area"]=="Area Unknown"):
        areanacount += 1
    ccnacount = 0
    if (lastdfdict[postcode]["Crime Count"]=="Crime Count Unknown"):
        ccnacount += 1
    retailnacount = 0
    if (lastdfdict[postcode]["Retail Count"]=="Retail Count Unknown"):
        retailnacount += 1
    if sum([lanacount,popnacount,dinacount,areanacount,ccnacount,retailnacount])>0:
        unknowndict[postcode]={"LA Unknown":lanacount,"Pop Unknown":popnacount,"DepInd Unknown":dinacount,"Area Unknown":areanacount,"CC Unknown":ccnacount,"Retail Unknown":retailnacount}
postcodes_to_drop=list(unknowndict.keys())

print("dropping any postcodes from lastdfdict with any NA values")

for postcode in list(lastdfdict.keys()):
    if postcode in postcodes_to_drop:
        del lastdfdict[postcode]
print(len(lastdfdict))


# Deprivation Rank compared to mean 

mediandepscore=statistics.median(alldepscores)
print(mediandepscore)
for postcode in list(lastdfdict.keys()):
    localauthority=lastdfdict[postcode]["local authority"]
    #print(localauthority)
    depscore=deprivation_scores_grouped.loc[localauthority][0]
    relativedepscore=depscore/mediandepscore
    lastdfdict[postcode]["Deprivation Score Relative to Nation Median"]=relativedepscore
lastdfdict["E10"]

# Total crimes per 1000 pop

for postcode in list(lastdfdict.keys()):
    relativecrimescore=lastdfdict[postcode]['Crime Count']/lastdfdict[postcode]['Population']
    lastdfdict[postcode]["Crimes per 1000"]=relativecrimescore
lastdfdict["E10"]

# LocAuth Crime rate compared to median Crime rate

allcrimerates=[]
for postcode in list(lastdfdict.keys()):
    allcrimerates.append(lastdfdict[postcode]["Crimes per 1000"])
allmediancrimes=statistics.median(allcrimerates)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Crime rate relative to National Median"]=lastdfdict[postcode]["Crimes per 1000"]/allmediancrimes
lastdfdict["E10"]


# Retail Businesses per Hectare

for postcode in list(lastdfdict.keys()):
    retailperhectare=lastdfdict[postcode]['Retail Count']/lastdfdict[postcode]['Area']
    lastdfdict[postcode]["Businesses per Hectere"]=retailperhectare
lastdfdict["E10"]

# LocAuth retail density compared to Median retail density

allretaildensity=[]
for postcode in list(lastdfdict.keys()):
    allretaildensity.append(lastdfdict[postcode]["Businesses per Hectere"])
allmedianretaildensity=statistics.median(allretaildensity)
for postcode in list(lastdfdict.keys()):
    lastdfdict[postcode]["Retail Score Relative to National Median"]=lastdfdict[postcode]["Businesses per Hectere"]/allmedianretaildensity
lastdfdict["KT1"]

# %%
lastdfdict["E10"]

# %%
lastdfdict = {key:val for key, val in lastdfdict.items() if lastdfdict[key]["Median Price"]<400000}
for key,val in lastdfdict.items():
    print(key,lastdfdict[key]["Median Price"])

# %%
maxmedprice=0
for postcode in list(lastdfdict.keys()):
    medprice=lastdfdict[postcode]["Median Price"]
    if medprice>maxmedprice:
        maxmedprice=medprice
print("maxprice",maxmedprice)
maxbusinesses=0
for postcode in list(lastdfdict.keys()):
    businessdens=lastdfdict[postcode]["Businesses per Hectere"]
    if businessdens>maxbusinesses:
        maxbusinesses=businessdens
print("maxbusinesses",maxbusinesses)
maxdeprank=0
for postcode in list(lastdfdict.keys()):
    deprank=lastdfdict[postcode]["Deprivation Rank"]
    if deprank>maxdeprank:
        maxdeprank=deprank
print("maxdep",maxdeprank)
maxcrimerank=0
for postcode in list(lastdfdict.keys()):
    crimerank=lastdfdict[postcode]["Crimes per 1000"]
    if crimerank>maxcrimerank:
        maxcrimerank=crimerank
print("maxcrime",maxcrimerank)
maxtimerank=0
for postcode in list(lastdfdict.keys()):
    timerank=lastdfdict[postcode]["Median Time"]
    if timerank>maxtimerank:
        maxtimerank=timerank
print("maxtime",maxtimerank)

# %%
lastdfdict["KT1"]

# %%
lastdfdict["KT6"]

# %%
for postcode in list(lastdfdict.keys()):
    price_score=(lastdfdict[postcode]['Median Price']/maxmedprice)**2
    # smaller is better
    retail_score=(lastdfdict[postcode]["Businesses per Hectere"]/maxbusinesses)
    # bigger is better
    deprivation_score=(lastdfdict[postcode]["Deprivation Rank"]/maxdeprank)**2
    # bigger is better
    crime_score=(lastdfdict[postcode]["Crimes per 1000"]/maxcrimerank)**1.25
    # smaller is better
    #time_score=(lastdfdict[postcode]["Median Time"]/maxtimerank)
    # smaller is better
    lastdfdict[postcode]["Total Score"]=(deprivation_score)/(price_score*crime_score)
    # bigger is better
outputdf=pd.DataFrame.from_dict(data=lastdfdict,orient="index")
outputdf=outputdf[["local authority","Median Price","Median Price over Median Area (Kingston Only)","Businesses per Hectere","Deprivation Rank","Crimes per 1000","Median Time","Total Score"]]
savedf=outputdf.sort_values(by="Total Score",ascending=False)
savedf.to_excel("revised_weighted_savedf_flats_national.xlsx")

# %%
savedf

# %%
savedfkt=savedf[savedf.index.str.startswith("KT")].sort_values(by="Total Score",ascending=False).head()
savedfsw=savedf[savedf.index.str.startswith("SW")].sort_values(by="Total Score",ascending=False).head()
savedftw=savedf[savedf.index.str.startswith("TW")].sort_values(by="Total Score",ascending=False).head()
savedffinal=pd.concat([savedfkt,savedfsw,savedftw])
savedffinal

# %%
savedf["Area"]=""
savedf["Sub-Area"]=""
savedf["Comment"]=""
savedf.loc["KT6","Area"]="Kingston"
savedf.loc["KT6","Sub-Area"]="Surbiton"
savedf.loc["KT6","Sub-Area"]="Surbiton"
savedf.loc["KT1","Area"]="Kingston"
savedf.loc["KT1","Sub-Area"]="Centre"
savedf.loc["SW14","Area"]="Kingston"
savedf.loc["SW14","Sub-Area"]="East Sheen"
savedf.loc["TW2","Area"]="Twickenham"
savedf.loc["TW2","Sub-Area"]="Whitton"
savedf.loc["TW1","Area"]="Twickenham"
savedf.loc["TW1","Sub-Area"]="Center"
savedf.loc["TW11","Area"]="Twickenham"
savedf.loc["TW11","Sub-Area"]="Teddington"
savedf.loc["TW12","Area"]="Twickenham"
savedf.loc["TW12","Sub-Area"]="Hampton"
#savedf.sort_values(by="Total Score",ascending=False)

# %%
savedf=savedf[savedf["Area"].str.len()>1]
savedf.sort_values(by="Total Score",ascending=False)

# %%
savedf.groupby('Area', as_index=False)['Total Score'].mean()

# %%
outputdf=outputdf[outputdf["local authority"]!="City of London"]
outputdf=outputdf[outputdf["local authority"]!="Westminster"]
outputdf[(outputdf["Median Time"]<75)].sort_values(by="Total Score",ascending=False)

# %%
outputdf[(outputdf["Postcode Median Price Relative to 2hr Radius Median Price"]<1) & (outputdf["Postcode Median Time Relative to 2hr Radius Median Time"]<1)].sort_values(by="Total Score",ascending=False)["local authority"].to_dict()
